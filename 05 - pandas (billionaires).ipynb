# %% [markdown]
# # Homework 5, Part 2: Answer questions with pandas
#
# **Use the Excel file to answer the following questions.** This is a little more typical of what your data exploration will look like with pandas.

# %% [markdown]
# ## 0) Setup
#
# Import pandas **with the correct name** and set `matplotlib` to always display graphics in the notebook.

# %%
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## 1) Reading in an Excel file
#
# Use pandas to read in the `richpeople.xlsx` Excel file, saving it as a variable with the "correct" name. You will use `read_excel` instead of `read_csv`, *but you'll also need to install a new library*.

# %%
df = pd.read_excel("richpeople.xlsx")

# %% [markdown]
# ## 2) Checking your data
#
# Display the number of rows and columns in your data. Also display the names and data types of each column.

# %%
df.shape
#There are 1653 rows and 30 columns
# Out:
# (1653, 30)

# %%
df.dtypes
# Out:
# year                         int64
# name                        object
# rank                         int64
# citizenship                 object
# countrycode                 object
# networthusbillion          float64
# selfmade                    object
# typeofwealth                object
# gender                      object
# age                        float64
# industry                    object
# IndustryAggregates          object
# region                      object
# north                        int64
# politicalconnection        float64
# founder                      int64
# generationofinheritance     object
# sector                      object
# company                     object
# companytype                 object
# relationshiptocompany       object
# foundingdate               float64
# gdpcurrentus               float64
# sourceofwealth              object
# notes                       object
# notes2                      object
# source                      object
# source_2                    object
# source_3                    object
# source_4                    object
# dtype: object

# %% [markdown]
# ## 3) Who are the top 10 richest billionaires? Use the `networthusbillion` column.

# %%
df.sort_values(by='networthusbillion', ascending = False).head(n=10)
# Out:
#       year              name  rank    citizenship countrycode  \
# 184   2014        Bill Gates     1  United States         USA
# 226   2014  Carlos Slim Helu     2         Mexico         MEX
# 79    2014    Amancio Ortega     3          Spain         ESP
# 1562  2014    Warren Buffett     4  United States         USA
# 862   2014     Larry Ellison     5  United States         USA
# 339   2014        David Koch     6  United States         USA
# 247   2014      Charles Koch     6  United States         USA
# 1364  2014   Sheldon Adelson     8  United States         USA
# 280   2014    Christy Walton     9  United States         USA
# 724   2014        Jim Walton    10  United States         USA
#
#       networthusbillion   selfmade              typeofwealth  gender   age  \
# 184                76.0  self-made       founder non-finance    male  58.0
# 226                72.0  self-made  privatized and resources    male  74.0
# 79                 64.0  self-made       founder non-finance    male  77.0
# 1562               58.2  self-made       founder non-finance    male  83.0
# 862                48.0  self-made       founder non-finance    male  69.0
# 339                40.0  inherited                 inherited    male  73.0
# 247                40.0  inherited                 inherited    male  78.0
# 1364               38.0  self-made         self-made finance    male  80.0
# 280                36.7  inherited                 inherited  female  59.0
# 724                34.7  inherited                 inherited    male  66.0
#
#        ...    relationshiptocompany foundingdate gdpcurrentus  \
# 184    ...                  founder       1975.0          NaN
# 226    ...                  founder       1990.0          NaN
# 79     ...                  founder       1975.0          NaN
# 1562   ...                  founder       1839.0          NaN
# 862    ...                  founder       1977.0          NaN
# 339    ...                 relation       1940.0          NaN
# 247    ...                 relation       1940.0          NaN
# 1364   ...                  founder       1952.0          NaN
# 280    ...                 relation       1962.0          NaN
# 724    ...                 relation       1962.0          NaN
#
#           sourceofwealth                  notes  notes2  \
# 184            Microsoft                    NaN     NaN
# 226              telecom                    NaN     NaN
# 79                retail                    NaN     NaN
# 1562  Berkshire Hathaway                    NaN     NaN
# 862               Oracle                    NaN     NaN
# 339          diversified  inherited from father     NaN
# 247          diversified  inherited from father     NaN
# 1364             casinos                    NaN     NaN
# 280             Wal-Mart                  widow     NaN
# 724             Wal-Mart  inherited from father     NaN
#
#                                                  source  \
# 184           http://www.forbes.com/profile/bill-gates/
# 226   http://www.ozy.com/provocateurs/carlos-slims-w...
# 79        http://www.forbes.com/profile/amancio-ortega/
# 1562  http://www.forbes.com/lists/2009/10/billionair...
# 862        http://www.forbes.com/profile/larry-ellison/
# 339   http://www.kochind.com/About_Koch/History_Time...
# 247   http://www.kochind.com/About_Koch/History_Time...
# 1364     http://www.forbes.com/profile/sheldon-adelson/
# 280       http://www.forbes.com/profile/christy-walton/
# 724           http://www.forbes.com/profile/jim-walton/
#
#                                                source_2 source_3 source_4
# 184                                                 NaN      NaN      NaN
# 226                                                 NaN      NaN      NaN
# 79                                                  NaN      NaN      NaN
# 1562  http://www.forbes.com/companies/berkshire-hath...      NaN      NaN
# 862   http://www.businessinsider.com/how-larry-ellis...      NaN      NaN
# 339                                                 NaN      NaN      NaN
# 247                                                 NaN      NaN      NaN
# 1364  http://lasvegassun.com/news/1996/nov/26/rat-pa...      NaN      NaN
# 280                                                 NaN      NaN      NaN
# 724                                                 NaN      NaN      NaN
#
# [10 rows x 30 columns]

# %% [markdown]
# ## 4) How many male billionaires are there compared to the number of female billionares? Do they have a different average wealth?
#
# > **TIP:** The second part uses `groupby`, but the first part does not.

# %%
df.groupby("gender")["gender"].count().plot(kind = "bar")
#Billionaires are disproportionately male

# %%
df.groupby("gender")["networthusbillion"].mean()
#Average wealth of women are slightly higher at 3.92 US billion versus men at 3.90 US billion.
# Out:
# gender
# female    3.920556
# male      3.902716
# Name: networthusbillion, dtype: float64

# %% [markdown]
# ## 5) Who is the poorest billionaire? Who are the top 10 poorest billionaires?

# %%
df.sort_values(by='rank').tail(n=10)
#The top 10 poorest billionaires are below. It's a 10 way tie for rank #1565 so there isn't a single poorest billionaire.
# Out:
#       year                name  rank    citizenship countrycode  \
# 485   2014             Fu Kwan  1565          China         CHN
# 1114  2014  Nerijus Numavicius  1565      Lithuania         LTU
# 1357  2014      Serhiy Tihipko  1565        Ukraine         UKR
# 1133  2014   O. Francis Biondi  1565  United States         USA
# 370   2014         Ding Shijia  1565          China         CHN
# 371   2014       Ding Shizhong  1565          China         CHN
# 567   2014   Harindarpal Banga  1565          India         IND
# 430   2014    Enrique Banuelos  1565          Spain         ESP
# 1086  2014    Monika Schoeller  1565        Germany         DEU
# 1376  2014        Shoji Uehara  1565          Japan         JPN
#
#       networthusbillion   selfmade              typeofwealth  gender   age  \
# 485                 1.0  self-made         self-made finance    male  56.0
# 1114                1.0  self-made       founder non-finance    male  46.0
# 1357                1.0  self-made         self-made finance    male  54.0
# 1133                1.0  self-made         self-made finance    male  49.0
# 370                 1.0  self-made                 executive    male  50.0
# 371                 1.0  self-made                 executive    male  43.0
# 567                 1.0  self-made  privatized and resources    male  63.0
# 430                 1.0  self-made         self-made finance    male  48.0
# 1086                1.0  inherited                 inherited  female  75.0
# 1376                1.0  inherited                 inherited    male  86.0
#
#        ...    relationshiptocompany foundingdate gdpcurrentus  \
# 485    ...                 chairman       1990.0          NaN
# 1114   ...                  founder       1992.0          NaN
# 1357   ...                  founder       1992.0          NaN
# 1133   ...                  founder       1995.0          NaN
# 370    ...          deputy chairman       1994.0          NaN
# 371    ...                 director       1966.0          NaN
# 567    ...            Vice Chairman       1986.0          NaN
# 430    ...                  founder       1982.0          NaN
# 1086   ...                 relation       1948.0          NaN
# 1376   ...                 relation       1912.0          NaN
#
#             sourceofwealth                  notes  notes2  \
# 485            diversified                    NaN     NaN
# 1114      retail, pharmacy                    NaN     NaN
# 1357  banking, agriculture                    NaN     NaN
# 1133            hedge fund                    NaN     NaN
# 370                  shoes                    NaN     NaN
# 371                 retail                    NaN     NaN
# 567            commodities                    NaN     NaN
# 430            real estate                    NaN     NaN
# 1086            publishing  inherited from father     NaN
# 1376       pharmaceuticals  inherited from father     NaN
#
#                                                  source  \
# 485              http://www.forbes.com/profile/fu-kwan/
# 1114              http://en.wikipedia.org/wiki/VP_Group
# 1357      http://www.forbes.com/profile/serhiy-tihipko/
# 1133    http://www.forbes.com/profile/o-francis-biondi/
# 370            http://en.wikipedia.org/wiki/Anta_Sports
# 371                  http://www.sce-re.com/en/about.asp
# 567    http://en.wikipedia.org/wiki/Noble_Group_Limited
# 430   http://en.wikipedia.org/wiki/Enrique_Ba%C3%B1u...
# 1086    http://www.forbes.com/profile/monika-schoeller/
# 1376       http://www.forbes.com/profile/shoji-uehara/#
#
#                                                source_2  \
# 485        http://www.macrolink.com.cn/en/AboutBig.aspx
# 1114  Shankill site hits a snag The Irish Times Marc...
# 1357            http://en.wikipedia.org/wiki/PrivatBank
# 1133  http://www.forbes.com/sites/nathanvardi/2014/0...
# 370            http://en.wikipedia.org/wiki/Ding_Shijia
# 371        http://www.forbes.com/profile/ding-shizhong/
# 567    http://www.forbes.com/profile/harindarpal-banga/
# 430   http://www.forbes.com/lists/2010/10/billionair...
# 1086                                                NaN
# 1376  http://en.wikipedia.org/wiki/Taisho_Pharmaceut...
#
#                                                source_3 source_4
# 485                                                 NaN      NaN
# 1114                                                NaN      NaN
# 1357  http://www.kyivpost.com/content/business/priva...      NaN
# 1133                                                NaN      NaN
# 370   http://www.bloomberg.com/research/stocks/peopl...      NaN
# 371                                                 NaN      NaN
# 567                                                 NaN      NaN
# 430                                                 NaN      NaN
# 1086                                                NaN      NaN
# 1376                                                NaN      NaN
#
# [10 rows x 30 columns]

# %% [markdown]
# ## 6) What is the most common source of wealth? Is it different between males and females?
#
# > **TIP:** You know how to `groupby` and you know how to count how many times a value is in a column. Can you put them together???

# %%
df["sourceofwealth"].value_counts()
#The most common source of wealth is real estate
# Out:
# real estate                          107
# diversified                           69
# retail                                63
# investments                           60
# pharmaceuticals                       42
# hedge funds                           34
# banking                               33
# construction                          32
# media                                 24
# consumer goods                        19
# software                              18
# private equity                        16
# finance                               15
# steel                                 13
# mining                                12
# chemicals                             12
# manufacturing                         12
# hotels, investments                   11
# casinos                               11
# insurance                             10
# telecom                               10
# Facebook                               9
# money management                       9
# oil                                    9
# electronics                            9
# education                              8
# beverages                              8
# commodities                            8
# beer                                   8
# cleaning products                      7
#                                     ...
# shipping, seafood                      1
# Celltrion                              1
# chewing gum                            1
# blinds                                 1
# soft drinks                            1
# Starbucks                              1
# cars                                   1
# alcohol                                1
# motors                                 1
# telecom, oil service, real estate      1
# DirecTV                                1
# industrial equipment                   1
# fasteners                              1
# Amazon.com                             1
# internet information provider          1
# retail, media                          1
# real estate, plush toys                1
# beauty products                        1
# insurance, beverages                   1
# metals, energy                         1
# TV, food                               1
# Amway                                  1
# shopping centers                       1
# medical supplies                       1
# autos                                  1
# retail, banking                        1
# mining, fisheries                      1
# Dole, real estate                      1
# Roche Holding                          1
# home improvement stores                1
# Name: sourceofwealth, Length: 616, dtype: int64

# %%
df[df["gender"] == "female"]["sourceofwealth"].value_counts().head(10)
#For women the most common source of wealth is diversified
# Out:
# diversified            9
# real estate            7
# media                  6
# hotels, investments    5
# consumer goods         5
# construction           5
# cleaning products      4
# casinos                4
# Wal-Mart               4
# chemicals              4
# Name: sourceofwealth, dtype: int64

# %%
df[df["gender"] == "male"]["sourceofwealth"].value_counts().head(10)
#For men the most common source of wealth is real estate
# Out:
# real estate        100
# diversified         60
# retail              60
# investments         58
# pharmaceuticals     40
# hedge funds         34
# banking             30
# construction        27
# media               18
# software            18
# Name: sourceofwealth, dtype: int64

# %% [markdown]
# ## 7) What companies have the most billionaires? Graph the top 5 as a horizontal bar graph.
#
# > **TIP:** First find the answer to the question, then just try to throw `.plot()` on the end
# >
# > **TIP:** You can use `.head()` on *anything*, not just your basic `df`
# >
# > **TIP:** You might feel like oyu should use `groupby`, but don't! There's an easier way to count.

# %%
df ["company"].value_counts ().head().plot(kind = 'barh')

# %% [markdown]
# ## 8) How much money do these billionaires have in total?

# %%
df["networthusbillion"].sum()
# Out:
# 6454.4000000000005

# %% [markdown]
# ## 9) What are the top 3 countries with the most money held by billionaires?
#
# I am **not** asking which country has the most billionaires - this is total amount of money per country.
#
# > **TIP:** Think about it in steps - "I want them organized by country," "I want their net worth," and "I want to add it all up." Just chain them all together.

# %%
df.groupby("countrycode")["networthusbillion"].sum()
# Out:
# countrycode
# AGO          3.7
# ARE         14.6
# ARG         11.3
# AUS         85.4
# AUT         33.8
# BEL          8.0
# BRA        192.2
# CAN        112.8
# CHE         80.2
# CHL         41.3
# CHN        375.8
# COL         30.6
# CYP         19.7
# CZE         18.4
# DEN         26.9
# DEU        401.4
# DZA          3.2
# EGY         15.6
# ESP        122.6
# FIN         13.3
# FRA        235.3
# GBR        152.0
# GEO          5.2
# GGY          2.4
# GRC          8.2
# HKG        213.7
# IDN         47.8
# IND        191.9
# IRL         25.5
# ISR         51.8
#            ...
# MAR          7.4
# MCO          4.6
# MEX        142.9
# MYS         53.1
# NGA         33.3
# NLD         24.2
# NOR         21.8
# NPL          1.1
# NZL          9.8
# OMN          2.3
# PER         11.9
# PHL         40.1
# POL         12.8
# PRT         10.6
# ROU          1.2
# RUS        422.5
# SAU         49.0
# SGP         45.1
# SWE        116.7
# SWZ          3.7
# THA         36.8
# TUR         43.2
# TZA          1.0
# Taiwan      75.8
# UGA          1.1
# UKR         26.6
# USA       2322.4
# VEN          9.0
# VNM          1.6
# ZAF         25.4
# Name: networthusbillion, Length: 69, dtype: float64

# %% [markdown]
# ## 10) How old is an average billionaire? How old are billionaires self made vs. non self made?

# %%
df["age"].mean()
#The mean age of a billionaire is 63 years old
# Out:
# 63.342138364779878

# %%
df["age"].median()
#The median age of a billionaire is 63
# Out:
# 63.0

# %%
df[df["selfmade"] == "inherited"]["age"].mean()
#The average age of a non self made billionaire is 65
# Out:
# 64.962184873949582

# %% [markdown]
# ## 11) Who are the youngest billionaires? Who are the oldest? Make a graph of the distribution of ages.

# %%
df.sort_values(by="age", ascending = False).head()
#The oldest billionaires are David Rockefeller, Karl Wlaschek, Kirk Kerkorian, Henry Hillman, and Erika Pohl-Stroher
# Out:
#      year                    name  rank    citizenship countrycode  \
# 343  2014  David Rockefeller, Sr.   580  United States         USA
# 816  2014           Karl Wlaschek   305        Austria         AUT
# 836  2014          Kirk Kerkorian   328  United States         USA
# 588  2014           Henry Hillman   687  United States         USA
# 435  2014      Erika Pohl-Stroher  1154        Germany         DEU
#
#      networthusbillion   selfmade         typeofwealth  gender   age   ...     \
# 343                2.9  inherited            inherited    male  98.0   ...
# 816                4.8  self-made  founder non-finance    male  96.0   ...
# 836                4.5  self-made    self-made finance    male  96.0   ...
# 588                2.5  inherited            inherited    male  95.0   ...
# 435                1.5  inherited            inherited  female  95.0   ...
#
#     relationshiptocompany foundingdate gdpcurrentus        sourceofwealth  \
# 343              relation       1870.0          NaN          oil, banking
# 816               founder       1953.0          NaN                retail
# 836              investor       1924.0          NaN  casinos, investments
# 588              relation       1942.0          NaN           investments
# 435              relation       1880.0          NaN         hair products
#
#                                                  notes  \
# 343  family made most of fortune in the late 19th a...
# 816                                                NaN
# 836                                  purchased in 1969
# 588                              inherited from father
# 435                                     3rd generation
#
#                        notes2  \
# 343                       NaN
# 816                       NaN
# 836                       NaN
# 588                       NaN
# 435  23% stake in the company
#
#                                                 source  \
# 343     http://en.wikipedia.org/wiki/David_Rockefeller
# 816                 http://en.wikipedia.org/wiki/BILLA
# 836        http://en.wikipedia.org/wiki/Kirk_Kerkorian
# 588       http://www.forbes.com/profile/henry-hillman/
# 435  http://www.forbes.com/profile/erika-pohl-stroher/
#
#                                           source_2  \
# 343      http://en.wikipedia.org/wiki/Standard_Oil
# 816     http://en.wikipedia.org/wiki/Karl_Wlaschek
# 836  http://www.forbes.com/profile/kirk-kerkorian/
# 588     http://en.wikipedia.org/wiki/Calgon_Carbon
# 435             http://en.wikipedia.org/wiki/Wella
#
#                                               source_3 source_4
# 343    http://en.wikipedia.org/wiki/Rockefeller_family      NaN
# 816  https://www.billa.at/Footer_Nav_Seiten/Geschic...      NaN
# 836  PROFILE: Las Vegas billionaire amassed his wea...      NaN
# 588                                                NaN      NaN
# 435                                                NaN      NaN
#
# [5 rows x 30 columns]

# %%
df.sort_values(by="age").head()
#The youngest billionaires are Perenna Kei, Dustin Moskovitz, Mark Zuckerberg, Anton Kathrein, and Drew Houston
# Out:
#       year                 name  rank    citizenship countrycode  \
# 1172  2014          Perenna Kei  1284      Hong Kong         HKG
# 397   2014     Dustin Moskovitz   202  United States         USA
# 1004  2014      Mark Zuckerberg    21  United States         USA
# 127   2014  Anton Kathrein, Jr.  1270        Germany         DEU
# 394   2014         Drew Houston  1372  United States         USA
#
#       networthusbillion   selfmade         typeofwealth  gender   age  \
# 1172                1.3  inherited            inherited  female  24.0
# 397                 6.8  self-made  founder non-finance    male  29.0
# 1004               28.5  self-made  founder non-finance    male  29.0
# 127                 1.4  inherited            inherited    male  29.0
# 394                 1.2  self-made  founder non-finance    male  30.0
#
#        ...    relationshiptocompany foundingdate gdpcurrentus  sourceofwealth  \
# 1172   ...                 relation       1996.0          NaN     real estate
# 397    ...                  founder       2004.0          NaN        Facebook
# 1004   ...                  founder       2004.0          NaN        Facebook
# 127    ...                 relation       1919.0          NaN        antennas
# 394    ...                  founder       2007.0          NaN         Dropbox
#
#                       notes  notes2  \
# 1172  inherited from father     NaN
# 397                     NaN     NaN
# 1004                    NaN     NaN
# 127          3rd generation     NaN
# 394                     NaN     NaN
#
#                                                  source  \
# 1172           http://en.wikipedia.org/wiki/Perenna_Kei
# 397       http://en.wikipedia.org/wiki/Dustin_Moskovitz
# 1004     http://www.forbes.com/profile/mark-zuckerberg/
# 127   http://www.forbes.com/profile/anton-kathrein-jr/#
# 394           http://en.wikipedia.org/wiki/Drew_Houston
#
#                                                source_2  \
# 1172  http://www.loganestate.com/en/about.aspx?ftid=294
# 397     http://www.forbes.com/profile/dustin-moskovitz/
# 1004                                                NaN
# 127                                                 NaN
# 394      http://en.wikipedia.org/wiki/Dropbox_(service)
#
#                                                source_3 source_4
# 1172                                                NaN      NaN
# 397   https://www.facebook.com/facebook/info?tab=pag...      NaN
# 1004                                                NaN      NaN
# 127                                                 NaN      NaN
# 394         http://www.forbes.com/profile/drew-houston/      NaN
#
# [5 rows x 30 columns]

# %%
df ["age"].value_counts().plot(kind="bar")

# %% [markdown]
# ## 12) Make a scatterplot of their net worth compared to their age

# %%
df.plot(kind = "scatter", x = "age", y = "networthusbillion")

# %% [markdown]
# ## 13) Make a bar graph of the top 10 richest billionaires

# %%
df.sort_values(by="networthusbillion").tail(10). plot(kind ='barh', x = 'name', y = 'networthusbillion')
