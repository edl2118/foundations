# %% [markdown]
# # Corporate Prosecution - Exercise B
#
# #### Summary
#
# Looking at corporate prosecutions over time, and the possible assignment of a compliance officer.
#
# #### Files
#
# - cpr-data.xls, "detailed information about every federal organizational prosecution since 2001, as well as deferred and non-prosecution agreements with organizations since 1990"
#
# #### Data Source(s)
#
# The UVA School of Law publishees a [Corpoate Prosecution Registry](http://lib.law.virginia.edu/Garrett/corporate-prosecution-registry/about.html)
#
# > The goal of this Corporate Prosecutions Registry is to provide comprehensive and up-to-date information on federal organizational prosecutions in the United States, so that we can better understand how corporate prosecutions are brought and resolved. We include detailed information about every federal organizational prosecution since 2001, as well as deferred and non-prosecution agreements with organizations since 1990.
#
# [Corpoate Prosecution Registry](http://lib.law.virginia.edu/Garrett/corporate-prosecution-registry/about.html)
#
# #### Skills
#
# - Working with CSV files
# - Counting and summarizing columns
# - Searching with strings
# - Extracting with strings

# %% [markdown]
# # Read in `cpr-data.csv`

# %%
import pandas as pd 

df = pd.read_csv("cpr-data.csv")
df.head()
# Out:
#    REC_ID                                 COMPANY DISPOSITION_TYPE  \
# 0     138  1st Union Transfer and Telegraph, Inc.             plea
# 1     139                3D Poultry Loading, Inc.             plea
# 2    2529                         3rd & Bell, LLC             plea
# 3     822                          41 Market Inc.             plea
# 4     140                            45,000, Inc.             plea
#
#                          PRIMARY_CRIME_CODE SWISS_BANK_PROGRAM  \
# 0                          Money Laundering                NaN
# 1                               Immigration                NaN
# 2                               Immigration                NaN
# 3  Controlled substances / Drugs / Meth Act                NaN
# 4                             Environmental                NaN
#
#                           USAO        COUNTRY FINANCIAL_INSTITUTION  \
# 0  Virginia - Eastern District  United States                   Yes
# 1  Arkansas - Western District  United States                    No
# 2                      Arizona  United States                    No
# 3  Georgia - Northern District  United States                    No
# 4  Louisiana - Middle District  United States                    No
#
#                                       CASE_NAME        CASE_ID  ...    \
# 0                     USA v. 1st Union Transfer  4:03-cr-00024  ...
# 1                     USA v. 3D Poultry Loading  2:04-cr-20061  ...
# 2  USA v. Danny's Management Services LLC et al  2:13-cr-01143  ...
# 3                         USA v. 41 Market Inc.  4:06-cr-00023  ...
# 4                              USA v. 45000 Inc  3:04-cr-00180  ...
#
#   PRIVACY_WAIVER REGULATORY_DISGORGEMENT_RESTITUTION_FORFEITURE  \
# 0            NaN                                            NaN
# 1            NaN                                            NaN
# 2            NaN                                            NaN
# 3            NaN                                            NaN
# 4            NaN                                            NaN
#
#   REGULATORY_FINE REG_AGENCY STATEMENT_OF_FACTS TOTAL_REGULATORY  \
# 0             NaN        NaN                NaN              NaN
# 1             NaN        NaN                NaN              NaN
# 2             NaN        NaN                NaN              NaN
# 3             NaN        NaN                NaN              NaN
# 4             NaN        NaN                NaN              NaN
#
#    UNRELATED_TERMS  AGMT_YEAR  SOURCE  NOTES
# 0              NaN     2003.0   PACER    NaN
# 1              NaN     2005.0   PACER    NaN
# 2              NaN     2014.0   PACER    NaN
# 3              NaN     2006.0   PACER    NaN
# 4              NaN     2005.0   PACER    NaN
#
# [5 rows x 56 columns]

# %% [markdown]
# ### Check that your dataframe has 3038 rows and 56 columns.

# %%
df.shape
# Out:
# (3038, 56)

# %% [markdown]
# ### List the columns and their data types

# %%
df.dtypes
# Out:
# REC_ID                                                                      int64
# COMPANY                                                                    object
# DISPOSITION_TYPE                                                           object
# PRIMARY_CRIME_CODE                                                         object
# SWISS_BANK_PROGRAM                                                         object
# USAO                                                                       object
# COUNTRY                                                                    object
# FINANCIAL_INSTITUTION                                                      object
# CASE_NAME                                                                  object
# CASE_ID                                                                    object
# DOCKET_NO                                                                  object
# DATE                                                                       object
# JUDGMENT_DATE                                                              object
# PLEA_DATE                                                                  object
# TICKER                                                                     object
# US_PUBLIC_CO                                                               object
# ADDITIONAL_REGULATORY_FINE_OR_PAYMENT                                     float64
# COMMUNITY_SERVICE_OR_OTHER                                                float64
# FINE                                                                      float64
# FORFEITURE_DISGORGEMENT                                                   float64
# PROBATION_LENGTH                                                          float64
# RESTITUTION                                                               float64
# TOTAL_PAYMENT                                                               int64
# ACCEPTS_RESPONSIBILITY                                                     object
# AGREEMENT_REQUIRED_NEW_POSITIONS                                           object
# AGREEMENT_REQUIRED_OUTSIDE_AUDITORS_OR_EXPERTS                             object
# CITATION_AND_DESCRIPTION                                                   object
# CIVIL_JUDGMENT_OR_SETTLEMENT                                               object
# COMPLIANCE_PROGRAM_DESCRIPTION                                             object
# COMPLIANCE_PROGRAM_REQUIRED_BY_AGREEMENT                                   object
# COMPLIANCE_REQUIRED_BY_REGULATORS                                          object
# CRIME_DESC                                                                 object
# DESCRIPTION_OF_PAYMENTS                                                    object
# DOES_AGREEMENT_DISCUSS_REASONS_OR_RELEVENT_CONSIDERATIONS_FOR_LENIENCY     object
# DOJ_CAN_UNILATERALLY_TERMINATE                                             object
# FINE_CALCULATION_INCLUDED                                                  object
# FINE_DESCRIPTION                                                           object
# INDEP_MONITOR_REQUIRED                                                     object
# MUST_COMPORT_WITH_USSG_OR_AUDIT_COMPLIANCE                                 object
# OTHER_AGREEMENT                                                            object
# OTHER_AGREEMENT_REQUIRED_GOVERNANCE_CHANGES                                object
# OTHER_COMPLIANCE_OFFICER_OR_CONSULTANT_REQUIRED                            object
# PARALLEL_CIVIL_SUIT                                                        object
# PARALLEL_REGULATORY_ACTION_OR_LOCAL_PROSECUTOR                             object
# PRE_AGREEMENT_COMPLIANCE                                                   object
# PRE_AGREEMENT_COMPLIANCE_DESCRIPTION                                       object
# PRIVACY_WAIVER                                                             object
# REGULATORY_DISGORGEMENT_RESTITUTION_FORFEITURE                            float64
# REGULATORY_FINE                                                           float64
# REG_AGENCY                                                                 object
# STATEMENT_OF_FACTS                                                         object
# TOTAL_REGULATORY                                                          float64
# UNRELATED_TERMS                                                            object
# AGMT_YEAR                                                                 float64
# SOURCE                                                                     object
# NOTES                                                                      object
# dtype: object

# %% [markdown]
# ### What do the following columns mean?
#
# - PRIMARY_CRIME_CODE
# - DISPOSITION_TYPE
# - AGREEMENT_TYPE
# - COUNTRY
# - FINE
# - TOTAL_PAYMENT
# - USAO
# - PROBATION_LENGTH
# - AGREEMENT_REQUIRED_NEW_POSITIONS
# - INDEP_MONITOR_REQUIRED

# %%
#Sourced from : http://lib.law.virginia.edu/Garrett/corporate-prosecution-registry/browse/data-dictionary.txt

#df['PRIMARY_CRIME_CODE']= the type of crime being prosecuted and can include any of the following:

# 	Accounting Fraud - federal crimes relating to false statements or entries, such as under 18 U.S.C. § 1001 (a)(3).
# 	Antitrust - prosecutions brought under the Sherman Antitrust Act's criminal provisions.
# 	APPS - violations of the Act to Prevent Pollution from Ships (APPS), 33 U.S.C. §§ 1905-1915.
# 	Bank Secrecy Act - prosecutors brought under the Bank Secrecy Act, including 18 U.S.C. § 5331-5332 regarding failure to file reports of financial transactions or lack of adequate controls to prevent money laundering
# 	Bribery - violations of federal bribery and gratuities statutes such as 18 U.S.C. § 201.
# 	Bribery - violations of federal bribery and gratuities statutes such as 18 U.S.C. § 201.
# 	Controlled Substances - these include violations of the Controlled Substances Act (CSA).
# 	Environmental - these include prosecutions brought under any of the range of federal environmental statutes, including the Act to Prevent Pollution from Ships, the Clean Air Act, the Clear Water Act, the Resource Conversation and Recovery Act, and statutes regulating marine pollution, handling of hazardous waste, and others.
# 	FCPA (Foreign Corrupt Practices Act) - these include criminal prosecutions brought under the FCPA's bribery provisions and willful violations of the internal controls and books and records provisions, 15 U.S.C. §§ 78dd-1, et seq. A useful federal resource guide explaining these provisions is available here.
# 	False Statements - these include prosecutions for making false statements to federal authorities under statutes including 18 U.S.C. § 1001.
# 	Firearms - violations of federal criminal firearms registration and sales statutes.
# 	Food - criminal violations of federal food safety laws including for adulterating or misbranding under the Federal Food, Drug, and Cosmetic Act (FDCA).
# 	Fraud - these include mail fraud and wire fraud prosecutions brought under 18 U.S.C. § 1341 and 1343, as well as other fraud crimes, such as conspiracy to defraud the federal government, 18 U.S.C. §371. However, health care fraud, securities fraud, and tax fraud cases are listed separately.
# 	Gambling - illegal gambling business under 18 U.S. Code § 1955 or violations of other federal gambling laws.
# 	Health Care Fraud - these include prosecutions brought under 18 U.S.C. § 1347.
# 	Immigration - these include prosecutions brought for violating immigration rules concerning employment of noncitizens and unlawful employment practices under 8 U.S.C. §1324a and b, as well as crimes concerning bringing in and harboring illegal aliens under 8 U.S.C. §1324.
# 	Import / Export - these include violations of U.S. customs regulations concerning imports and exports as well as violations of U.S. sanctions regarding international trade and financial transactions, including violations of the International Emergency Economic Powers Act (IEEPA).
# 	Kickbacks - violation of the federal anti-kickback statutes, including 42 U.S. Code § 1320a-7b.
# 	Money Laundering - these include prosecutions brought under 18 U.S.C.§1956-1957 and under 18 U.S.C. §5324 regarding structuring transactions to evade reporting requirements.
# 	Obstruction of Justice - these include prosecutions brought under 18 U.S.C. § 1503 and companion statutes.
# 	OSHA - workplace safety crimes, involving the willful violation of a worker safety standard in the Occupational Safety and Health Act, as well as other workplace safety statutes such as and the Federal Mine Safety and Health Act.
# 	Other - additional federal crimes, of which there are many, that do not fall within the categories described here.
# 	Pharmaceutical - these include prosecutions brought under the Federal Food, Drug, and Cosmetic Act (FDCA) as well as anti-kickback and other related claims involving pharmaceutical sales and branding.
# 	Securities Fraud - these include prosecutions brought under 18 U.S.C. § 1348.
# 	Tax Fraud - these include prosecutions brought under 26 U.S.C. § 7201 and 7201 regarding attempted federal tax evasion and fraud and false statements to tax authorities.
# 	Wildlife - prosecutions under wildlife conversation laws including under Endangered Species Act and the Lacey Act.


#df['DISPOSITION_TYPE']= Indicates whether the prosecution was resolved through a type of agreement: a plea ("plea"); non-prosecution agreement ("NP"); or deferred prosecution agreement ("DP"); or whether the prosecution was resolved at trial in a conviction ("trial conviction") or acquittal ("acquittal") or a dismissal before or during trial ("dismissal"); as well as by a declination in which the case was dismissed by the prosecutor ("declination").

#df['AGREEMENT_TYPE'] = Indicates whether the agreement is a plea ("plea"), non-prosecution agreement ("NP"), or deferred prosecution agreement ("DP") CASE_ID - Docket number assigned by the court.

#df['COUNTRY']= Country in which the entity was incorporated.

#df['FINE'] = Amount of fine in U.S. dollars.

#df['TOTAL_PAYMENT'] = Sum of all monetary penalties (i.e. fines, restitution, forfeiture, disgorgements, community service, etc.)

#df['USAO'] = U.S. Attorney's Offices involved in the prosecution. Multiple entries are separated by a "|".

#df['PROBATION_LENGTH']= Length of probation in months.

#df['AGREEMENT_REQUIRED_NEW_POSITIONS']= the agreement stated that new positions be created at a firm, typically related to compliance

#df['INDEP_MONITOR_REQUIRED']= does the agreement require that an independent actor be retained to supervise implementation of a compliance program

# %% [markdown]
# # Customizing the display in pandas
#
# See how the middle of the table has a `...`? Let's fix that.
#
# ## How do you see the number of columns pandas will display?

# %%
pd.options.display.max_columns
# Out:
# 20

# %% [markdown]
# ## Set pandas to display 65 columns

# %%
pd.options.display.max_columns = 65

# %%
pd.options.display.max_columns
# Out:
# 65

# %% [markdown]
# ## How do you see the number of rows pandas will display? Then, set it to display 100 rows at a time.
#
# What does "the number rows pandas will display" actually mean?

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.max_rows= 100

# %% [markdown]
# ## Describe the TOTAL_PAYMENT column to me numerically - maxes, mins, averages.
#
# Do this in **one line.**

# %%
df['TOTAL_PAYMENT'].describe()
# Out:
# count    3.038000e+03
# mean     2.284273e+07
# std      1.556977e+08
# min      0.000000e+00
# 25%      2.189200e+04
# 50%      2.000000e+05
# 75%      2.100000e+06
# max      4.486800e+09
# Name: TOTAL_PAYMENT, dtype: float64

# %% [markdown]
# ### Oh that's ugly ugly ugly. Set pandas to format floats with 2 decimal points, we probably don't need to be more specific than that. Oh, and tell it to use a `,` in the thousands position!
#
# I'm just going to leave [this here](http://infohost.nmt.edu/~shipman/doc/python27/web/new-str-format.html) for reference. You should definitely come up and ask on the board, though.

# %%
pd.set_option("display.float_format", "{:,.2f}".format)

# %%
df['TOTAL_PAYMENT'].describe()
# Out:
# count           3,038.00
# mean       22,842,732.11
# std       155,697,740.02
# min                 0.00
# 25%            21,892.00
# 50%           200,000.00
# 75%         2,100,000.00
# max     4,486,800,000.00
# Name: TOTAL_PAYMENT, dtype: float64

# %% [markdown]
# ## Look at the fine and the forfeiture disgorgement for the first two rows. Pretty nice!

# %%
df[['FINE', 'FORFEITURE_DISGORGEMENT']].head(2)
# Out:
#        FINE  FORFEITURE_DISGORGEMENT
# 0      0.00               272,734.00
# 1 24,000.00                      nan

# %% [markdown]
# # A little summarizing

# %% [markdown]
# ## How many of cases actually went to trial? How did most of these cases arrive at a decision?

# %%
df['DISPOSITION_TYPE'].value_counts()
# Out:
# plea                              2565
# non-prosecution agreement          266
# deferred prosecution agreement     201
# dismissal                            2
# declination                          2
# trial convicton                      2
# Name: DISPOSITION_TYPE, dtype: int64

# %%
df['DISPOSITION_TYPE'].replace('NP', 'non-prosecution agreement', inplace=True)

# %%
df['DISPOSITION_TYPE'].replace('DP', 'deferred prosecution agreement', inplace=True)

# %%
#Only 2 cases went to trial. The vast majority had a plea bargain
df['DISPOSITION_TYPE'].value_counts()
# Out:
# plea                              2565
# non-prosecution agreement          266
# deferred prosecution agreement     201
# dismissal                            2
# declination                          2
# trial convicton                      2
# Name: DISPOSITION_TYPE, dtype: int64

# %% [markdown]
# ### Graph the previous answer, with the longest bar on top

# %%
% matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df['DISPOSITION_TYPE'].value_counts().sort_values().plot(kind='barh')

# %% [markdown]
# ## What's the distribution of total payments look like?

# %%
df['TOTAL_PAYMENT'].hist()

# %% [markdown]
# ## Sort by total payments, descending

# %%
df.sort_values (by = "TOTAL_PAYMENT", ascending = False)
# Out:
#       REC_ID                                     COMPANY DISPOSITION_TYPE  \
# 307     2548                            BNP Paribas S.A.             plea
# 309      983           BP Exploration & Production, Inc.             plea
# 2913    3147                               Volkswagen AG             plea
# 1000    2801               Evergreen International, S.A.             plea
# 753     2570                               Credit Suisse             plea
# 1454     757                   JPMorgan Chase Bank, N.A.               DP
# 2167     451                          Pharmacia & Upjohn             plea
# 1238      64     HSBC Bank USA, N.A. & HSBC Holdings plc               DP
# 2760     761                          Toyota Motor Corp.               DP
# 1168    1458                         Glaxosmithkline LLC             plea
# 636     3138                                    Citicorp             plea
# 1154      54                              General Motors               DP
# 164     2541                   Alstom Network Schweiz AG             plea
# 75       646                     Adelphia Communications               NP
# 358     3072                                Barclays PLC             plea
# 61       849                         Abbott Laboratories             plea
# 675     2519                              Commerzbank AG               DP
# 852      781                            Deutsche Bank AG               DP
# 957     1351                                   Eli Lilly             plea
# 2031    2938         Olympus Corporation of the Americas               DP
# 2815     122                                      UBS AG               DP
# 2331     479          Republic New York Securities Corp.             plea
# 851      670                            Deutsche Bank AG               DP
# 1452    3139                        JP Morgan Chase & Co             plea
# 2722    3059                       The Western Union Co.               DP
# 335     3051                 Bank Julius Baer & Co. Ltd.               DP
# 458     3144                                Braskem S.A.             plea
# 959     2796                             Eli Lilly & Co.             plea
# 2687    3010                            Tenet Healthcare               NP
# 33         3                          ABN AMRO Bank N.V.               DP
# 2456     104    Science Applications International Corp.               DP
# 55       844                          AU Optronics Corp.  trial convicton
# 1194     686                                      Google               NP
# 2696    3045          Teva Pharmaceutical Industries LTD               DP
# 3016    2509                                Yazaki Corp.             plea
# 393     1017        Berkeley Premium Nutraceuticals Inc.             plea
# 1512     607                                        KPMG               DP
# 2505    2213                  Siemens Aktiengesellschaft             plea
# 460     2551                                 Bridgestone             plea
# 1538     363                   Kellogg Brown & Root, LLC             plea
# 1584     377                     LG Display America Inc.             plea
# 502     1082                        CG Nutritionals Inc.             plea
# 2814     124                                      UBS AG               NP
# 2772    2363                  Transocean Deepwater, Inc.             plea
# 294      185                             BAE Systems PLC             plea
# 2380    3071                Royal Bank of Scotland (RBS)             plea
# 144      896                                    Allergan             plea
# 1563    3050                      Kolon Industries, Inc.             plea
# 295      659                                BAWAG P.S.K.               NP
# 1468    1627               Janssen Pharmaceuticals, Inc.             plea
# ...      ...                                         ...              ...
# 2713    2333                The Omega Group Chicago Inc.             plea
# 566      210  Carolina Upgrading of South Carolina, Inc.             plea
# 1973    1905                     Norcross Industrie Sarl             plea
# 2709    2330                    The Lacteos Factory Inc.             plea
# 2060    1955     Oxford Construction & Development Corp.             plea
# 2424    2166                           Sale Trucking LLC             plea
# 1513    1652                         KPS Texas Dev. Inc.             plea
# 278      656                                Aurora Foods               NP
# 1082    1405                    Forsyth Enterprises Inc.             plea
# 2425    2730                            Salomon Brothers               NP
# 1601    1700                     Lake Road Warehouse Co.             plea
# 1003     596                                    Exactech               DP
# 2430    2673                 Samsung Semiconductor, Inc.             plea
# 2697    2323              Texamerican Food Blending Inc.             plea
# 1213    1485         Greybor Medical Transportation Inc.             plea
# 1518    1655                       Kaizo Industries Inc.             plea
# 2437    2174             Santorini R.E. Investments Ltd.             plea
# 1597    2619                Laboratorios Tornel SA De CV             plea
# 2688    2318                               Teneyck Inc..             plea
# 2441    2178                                 Sarah's LLC             plea
# 552       32                            CareFusion Corp.               NP
# 551     1111     Cardiovascular Surgical Associates Inc.             plea
# 1604    2841                   Lakewood Construction Co.             plea
# 2718    3100         The Terminix International Co. L.P.             plea
# 1195     311              Gordon-Smith Contracting, Inc.             plea
# 270      966                         Atlas Central Corp.             plea
# 2101    1979                      Palmer Industries Inc.             plea
# 254     2717                             Arthur Anderson               DP
# 255      956                                 Asdico Inc.             plea
# 2147      94                            Penn Traffic Co.               NP
# 1891    2859                           NMC Homecare Inc.             plea
# 2146    2005                                 Penel Corp.             plea
# 2741    3115       Timothy J. Smith dba S&S Salvage, LLC             plea
# 2391     486        S Corp Construction Management, Inc.             plea
# 2392    2147                        S&H Script Shop Inc.             plea
# 2393    2148                      S.B.G. Management Inc.             plea
# 2737    2909                              Tiernay Metals             plea
# 263     2758                        Asset Security Corp.             plea
# 583     1137                             Cedarwood Corp.             plea
# 582     1136                     Cedar Distributors Inc.             plea
# 2731    2347                      Three Generations Inc.             plea
# 2405    2157                      SDI Future Health Inc.             plea
# 1010     276                    Extreme Associates, Inc.             plea
# 1200     765   Grand Junction Regional Airport Authority               NP
# 932     1337                          Eagle Station Inc.             plea
# 1302    1535                Hi-Tech Pharmaceuticals Inc.             plea
# 2724    2340          Therapy Charter Fishing Yacht Inc.             plea
# 1616    2728                               Lazard Freres               NP
# 269      965                       Atlantic Wire Co. LLC             plea
# 216      933                       Animal Power SA DE CV             plea
#
#                             PRIMARY_CRIME_CODE SWISS_BANK_PROGRAM  \
# 307                            Import / Export                NaN
# 309                              Environmental                NaN
# 2913                           Fraud - General                NaN
# 1000       Act to Prevent Pollution from Ships                NaN
# 753                                Fraud - Tax                NaN
# 1454                          Bank Secrecy Act                 No
# 2167                       Fraud - Health Care                NaN
# 1238                          Bank Secrecy Act                 No
# 2760                           Fraud - General                 No
# 1168                             FDCA / Pharma                NaN
# 636                                  Antitrust                NaN
# 1154                           Fraud - General                 No
# 164                                       FCPA                NaN
# 75                          Fraud - Securities                 No
# 358                            Fraud - General                NaN
# 61                               FDCA / Pharma                NaN
# 675                           Bank Secrecy Act                 No
# 852                                  Antitrust                 No
# 957                              FDCA / Pharma                NaN
# 2031                                 Kickbacks                 No
# 2815                               Fraud - Tax                 No
# 2331                           Fraud - General                NaN
# 851                                Fraud - Tax                 No
# 1452                                 Antitrust                NaN
# 2722                          Bank Secrecy Act                 No
# 335                                Fraud - Tax                 No
# 458                            Fraud - General                NaN
# 959                              FDCA / Pharma                NaN
# 2687                           Fraud - General                 No
# 33                            Bank Secrecy Act                 No
# 2456                           Fraud - General                 No
# 55                                   Antitrust                NaN
# 1194                             FDCA / Pharma                 No
# 2696                                      FCPA                 No
# 3016                                 Antitrust                NaN
# 393                           Money Laundering                NaN
# 1512                               Fraud - Tax                 No
# 2505                                      FCPA                NaN
# 460                                  Antitrust                NaN
# 1538                                      FCPA                NaN
# 1584                                 Antitrust                NaN
# 502                     Obstruction of Justice                NaN
# 2814                           Fraud - General                 No
# 2772                             Environmental                NaN
# 294                            Import / Export                NaN
# 2380                           Fraud - General                NaN
# 144                              FDCA / Pharma                NaN
# 1563                                     Other                NaN
# 295                         Fraud - Securities                 No
# 1468                             FDCA / Pharma                NaN
# ...                                        ...                ...
# 2713                           Fraud - General                NaN
# 566                              Environmental                NaN
# 1973                             Environmental                NaN
# 2709                           Import / Export                NaN
# 2060                           Fraud - General                NaN
# 2424                             Environmental                NaN
# 1513                           Fraud - General                NaN
# 278                         Fraud - Accounting                 No
# 1082                           Fraud - General                NaN
# 2425                        Fraud - Securities                 No
# 1601                             Environmental                NaN
# 1003                                 Kickbacks                 No
# 2430                                 Antitrust                NaN
# 2697                                      Food                NaN
# 1213                       Fraud - Health Care                NaN
# 1518                             Environmental                NaN
# 2437                           Fraud - General                NaN
# 1597  Controlled substances / Drugs / Meth Act                NaN
# 2688                           Fraud - General                NaN
# 2441                                     Other                NaN
# 552                              FDCA / Pharma                 No
# 551                                      Other                NaN
# 1604                             Environmental                NaN
# 2718                             Environmental                NaN
# 1195                             Environmental                NaN
# 270                                    Bribery                NaN
# 2101                           Fraud - General                NaN
# 254                            Fraud - General                 No
# 255   Controlled substances / Drugs / Meth Act                NaN
# 2147                        Fraud - Securities                 No
# 1891                                 Kickbacks                NaN
# 2146                           Fraud - General                NaN
# 2741                             Environmental                NaN
# 2391                               Fraud - Tax                NaN
# 2392  Controlled substances / Drugs / Meth Act                NaN
# 2393                           Fraud - General                NaN
# 2737                                 Antitrust                NaN
# 263                            Fraud - General                NaN
# 583                            Fraud - General                NaN
# 582                            Import / Export                NaN
# 2731                           Fraud - General                NaN
# 2405                                 Kickbacks                NaN
# 1010                           Fraud - General                NaN
# 1200                           Fraud - General                 No
# 932                                      Other                NaN
# 1302                           Fraud - General                NaN
# 2724                                      Food                NaN
# 1616                        Fraud - Securities                 No
# 269                              Environmental                NaN
# 216   Controlled substances / Drugs / Meth Act                NaN
#
#                                                    USAO         COUNTRY  \
# 307   New York - Southern District,USDOJ - Criminal ...          France
# 309                        Louisiana - Eastern District      non - U.S.
# 2913                        Michigan - Eastern District          German
# 1000  USDOJ - Criminal Division (California - Centra...   United States
# 753                         Virginia - Eastern District      non - U.S.
# 1454                       New York - Southern District   United States
# 2167                                      Massachusetts   United States
# 1238  New York - Eastern District,USDOJ - Criminal D...  United Kingdom
# 2760                       New York - Southern District      non - U.S.
# 1168                                      Massachusetts  United Kingdom
# 636               USDOJ - Antitrust Division (New York)   United States
# 1154                       New York - Southern District   United States
# 164   USDOJ - Criminal Division - Fraud Section,Conn...     Switzerland
# 75                         New York - Southern District   United States
# 358                                         Connecticut  United Kingdom
# 61    USDOJ - Consumer Protection Branch,Virginia - ...   United States
# 675   District of Columbia,New York - Southern Distr...      non - U.S.
# 852   USDOJ - Antitrust Division,USDOJ - Criminal Di...      non - U.S.
# 957   USDOJ - Civil Division - Office of Consumer Li...   United States
# 2031                                         New Jersey   United States
# 2815   Florida - Southern District,USDOJ - Tax Division     Switzerland
# 2331                       New York - Southern District   United States
# 851   New York - Southern District,USDOJ - Tax Division      non - U.S.
# 1452              USDOJ - Antitrust Division (New York)   United States
# 2722  USDOJ - Criminal Division - Money Laundering &...   United States
# 335                        New York - Southern District     Switzerland
# 458                         New York - Eastern District          Brazil
# 959   Pennsylvania - Eastern District,USDOJ - Civil ...   United States
# 2687  USDOJ - Criminal Division - Fraud Section|Geor...   United States
# 33    USDOJ - Criminal Division - Asset Forfeiture &...     Netherlands
# 2456                       New York - Southern District   United States
# 55           USDOJ - Antitrust Division (San Francisco)          Taiwan
# 1194                                       Rhode Island   United States
# 2696          USDOJ - Criminal Division - Fraud Section          Israel
# 3016                        Michigan - Eastern District           Japan
# 393   Ohio - Southern District,USDOJ - Office of Con...   United States
# 1512                       New York - Southern District   United States
# 2505  District of Columbia,USDOJ - Criminal Division...         Germany
# 460                USDOJ - Antitrust Division (Chicago)      non - U.S.
# 1538  Texas - Southern District (Financial Litigatio...   United States
# 1584                         USDOJ - Antitrust Division     South Korea
# 502                        Illinois - Southern District   United States
# 2814          USDOJ - Criminal Division - Fraud Section     Switzerland
# 2772                       Louisiana - Eastern District   United States
# 294   USDOJ - Criminal Division,USDOJ - National Sec...  United Kingdom
# 2380                                        Connecticut  United Kingdom
# 144                         Georgia - Northern District   United States
# 1563  Virginia - Eastern District|USDOJ - Criminal D...   United States
# 295                        New York - Southern District         Austria
# 1468                    Pennsylvania - Eastern District   United States
# ...                                                 ...             ...
# 2713                        Florida - Northern District   United States
# 566                                      South Carolina   United States
# 1973                                            Arizona   United States
# 2709                        Florida - Southern District   United States
# 2060              USDOJ - Antitrust Division (New York)   United States
# 2424                                              Idaho   United States
# 1513                          Texas - Southern District   United States
# 278                        New York - Southern District   United States
# 1082                        Virginia - Western District   United States
# 2425                                                NaN   United States
# 1601                        Missouri - Western District   United States
# 1003                                         New Jersey   United States
# 2430         USDOJ - Antitrust Division (San Francisco)   United States
# 2697                        Arkansas - Western District   United States
# 1213  USDOJ - Criminal Division (California - Centra...   United States
# 1518  USDOJ - Criminal Division (California - Centra...   United States
# 2437                          Texas - Southern District   United States
# 1597  USDOJ - Criminal Division (California - Southe...          Mexico
# 2688              USDOJ - Antitrust Division (New York)   United States
# 2441                                     South Carolina   United States
# 552                                              Kansas   United States
# 551                                              Oregon   United States
# 1604                       New York - Northern District   United States
# 2718                                     Virgin Islands   United States
# 1195                        New York - Western District   United States
# 270                            Ohio - Northern District   United States
# 2101                          Georgia - Middle District   United States
# 254                                         Connecticut   United States
# 255                         New York - Western District   United States
# 2147                       New York - Northern District   United States
# 1891                                      Massachusetts   United States
# 2146                                         New Jersey   United States
# 2741                        Kentucky - Western District   United States
# 2391                                            Arizona   United States
# 2392                           Texas - Western District   United States
# 2393                           Ohio - Northern District   United States
# 2737                         USDOJ - Antitrust Division   United States
# 263   Florida - Southern District,Florida - Southern...   United States
# 583                Ohio - Southern District,other gov't   United States
# 582                         Florida - Southern District   United States
# 2731  Missouri - Eastern District,Missouri - Eastern...   United States
# 2405                                             Nevada   United States
# 1010                    Pennsylvania - Western District   United States
# 1200                                           Colorado   United States
# 932                           Georgia - Middle District   United States
# 1302                        Georgia - Northern District   United States
# 2724                        Florida - Southern District   United States
# 1616                                      Massachusetts   United States
# 269                                         Connecticut   United States
# 216   USDOJ - Criminal Division (California - Southe...          Mexico
#
#      FINANCIAL_INSTITUTION                                          CASE_NAME  \
# 307                    Yes                            USA v. BNP Paribas S.A.
# 309                     No          USA v. BP Exploration and Production, Inc
# 2913                    No                                USA v. Liang et al.
# 1000                    No                         USA v. Evergreen Int, S.A.
# 753                    Yes                            USA v. Credit Suisse AG
# 1454                   Yes                                                NaN
# 2167                    No             USA v. Pharmacia & Upjohn Company Inc.
# 1238                   Yes                                                NaN
# 2760                    No                                                NaN
# 1168                    No                         USA v. Glaxosmithkline LLC
# 636                    Yes                                    USA v. Citicorp
# 1154                    No                                                NaN
# 164                     No                  USA v. Alstom Network Schweiz A G
# 75                      No                                                NaN
# 358                    Yes                                USA v. Barclays PLC
# 61                      No                         USA v. Abbott Laboratories
# 675                    Yes                                                NaN
# 852                    Yes                                                NaN
# 957                     No                       USA v. ELI LILLY AND COMPANY
# 2031                   NaN                                                NaN
# 2815                   Yes                                                NaN
# 2331                    No                        USA v. Republic NY Securiti
# 851                    Yes                                                NaN
# 1452                   NaN                       USA v. JP Morgan Chase & Co.
# 2722                   Yes                   USA v. The Western Union Company
# 335                    Yes                                                NaN
# 458                     No                                USA v. Braskem S.A.
# 959                     No                       USA v. ELI LILLY AND COMPANY
# 2687                   NaN                                                NaN
# 33                     Yes                                                NaN
# 2456                    No                                                NaN
# 55                      No                                   USA v. Lin et al
# 1194                    No                                                NaN
# 2696                   NaN              USA v. Teva Pharmaceutical Industries
# 3016                    No     United States of America v. Yazaki Corporation
# 393                     No                               USA v. Warshak et al
# 1512                   Yes                                                NaN
# 2505                    No                  USA v. SIEMENS AKTIENGESELLSCHAFT
# 460                     No  United States of America v. Bridgestone Corpor...
# 1538                    No                    USA v. Kellogg Brown & Root LLC
# 1584                    No                   USA v. LG Display Co. Ltd. et al
# 502                     No                         USA v. CG Nutritionals Inc
# 2814                   Yes                                                NaN
# 2772                    No                  USA v. Transocean Deepwater, Inc.
# 294                     No                             USA v. BAE SYSTEMS PLC
# 2380                   Yes              USA v. The Royal Bank of Scotland PLC
# 144                     No                               USA v. Allergan Inc.
# 1563                   NaN                USA v. Kolon Industries, Inc. et al
# 295                     No                                                NaN
# 1468                    No               USA v. JANSSEN PHARMACEUTICALS, INC.
# ...                    ...                                                ...
# 2713                    No                               USA v. BANDARI et al
# 566                     No                                       USA v. Adams
# 1973                    No                                 USA v. Grant et al
# 2709                    No                                 USA v. Lopez et al
# 2060                    No                                 USA v. Yaron et al
# 2424                    No                           USA v. Sale Trucking LLC
# 1513                    No                                      USA v. Sweezy
# 278                     No                                                NaN
# 1082                    No                               USA v. Forsyth et al
# 2425                    No                                                NaN
# 1601                    No                     USA v. Lake Road Warehouse Co.
# 1003                    No                                                NaN
# 2430                    No  USA v. Samsung Electronics Company, Limited et al
# 2697                    No                             USA v. Yarbrough et al
# 1213                    No                                USA v. Shpirt et al
# 1518                    No                  USA v. Kaizo Industries Inc et al
# 2437                    No                                      USA v. Sweezy
# 1597                    No                  USA v. Laboratorios Tornel, et al
# 2688                    No                                     USA v. Grobart
# 2441                    No                                 USA v. Sarah's LLC
# 552                     No                                                NaN
# 551                     No      USA v. Cardiovascular Surgical Associates Inc
# 1604                    No                             USA v. Lakewood Const.
# 2718                   NaN  USA v. THE TERMINIX INTERNATIONAL COMPANY LIMI...
# 1195                    No                                USA v. Gordon-Smith
# 270                     No                          USA v. Atlas Central Corp
# 2101                    No                     USA v. Palmer Industries et al
# 254                     No                                                NaN
# 255                     No                                USA v. Scheur et al
# 2147                    No                                                NaN
# 1891                    No                    USA v. NMC Homecare. Inc. et al
# 2146                    No                                 USA v. Smith et al
# 2741                   NaN                                       USA v. SMITH
# 2391                    No                          USA et al v. Sucato et al
# 2392                    No                                 USA v. Stallknecht
# 2393                    No          United States of America v. Shulman et al
# 2737                    No                                                NaN
# 263                     No                               USA v. Brandau et al
# 583                     No                                USA v. Bogart et al
# 582                     No                                 USA v. Mehdi et al
# 2731                    No                      USA v. Three Generations Inc.
# 2405                    No                USA vs SDI Future Health Inc. et al
# 1010                    No                    USA v. EXTREME ASSOCIATES et al
# 1200                    No                                                NaN
# 932                     No                                      USA v. Hedden
# 1302                    No                                 USA v. Wheat et al
# 2724                    No                                USA v. Saffan et al
# 1616                    No                                                NaN
# 269                     No                        USA v. Atlantic Wire Co LLC
# 216                     No                               USA v. Denkall et al
#
#             CASE_ID DOCKET_NO        DATE JUDGMENT_DATE   PLEA_DATE  \
# 307   1:14-cr-00460        54  2015-05-01    2015-05-01  2014-07-10
# 309   2:12-cr-00292        65  2013-01-29    2013-01-29  2013-01-30
# 2913  2:16-cr-20394       NaN  2017-04-21    2017-04-21         NaN
# 1000  2:05-cr-00238        27  2005-04-20    2005-04-20  2005-04-20
# 753   1:14-cr-00188        47  2014-11-21    2014-11-21  2014-05-19
# 1454            NaN       NaN  2014-01-06           NaN         NaN
# 2167  1:07-cr-10099        11  2007-04-26    2007-04-26  2007-04-03
# 1238            NaN       NaN  2012-12-11           NaN         NaN
# 2760            NaN       NaN  2014-03-09           NaN         NaN
# 1168  1:12-cr-10206        13  2012-07-10    2012-07-10  2012-07-02
# 636   3:15-cr-00078       NaN  2017-01-10    2017-01-10  2015-05-20
# 1154            NaN       NaN  2015-09-17           NaN         NaN
# 164   3:14-cr-00245        29  2015-11-25    2015-11-25  2014-12-22
# 75              NaN       NaN  2005-05-01           NaN         NaN
# 358   3:15-cr-00077       NaN  2017-01-10    2017-01-10  2015-05-20
# 61    1:12-cr-00026        18  2012-10-02    2012-10-02  2012-05-07
# 675             NaN       NaN  2015-03-12           NaN         NaN
# 852             NaN       NaN  2015-04-23           NaN         NaN
# 957             NaN         0  2009-01-30           NaN         NaN
# 2031            NaN       NaN  2016-02-29           NaN         NaN
# 2815            NaN       NaN  2009-02-18           NaN         NaN
# 2331  1:01-cr-01180         7  2002-01-10    2002-01-10  2001-12-17
# 851             NaN       NaN  2010-12-21           NaN         NaN
# 1452  3:15-cr-00079       NaN  2017-01-10    2017-01-10  2015-05-20
# 2722  1:17-cr-00011       NaN  2017-01-19           NaN         NaN
# 335   1:16-cv-00886       NaN  2016-02-04           NaN         NaN
# 458   1:16-cr-00644       NaN  2017-01-26    2017-01-26  2016-12-21
# 959   2:09-cr-00020        10  2009-01-30    2009-01-30  2009-01-15
# 2687            NaN       NaN  2016-09-30           NaN         NaN
# 33              NaN       NaN  2010-05-10           NaN         NaN
# 2456            NaN       NaN  2012-03-08           NaN         NaN
# 55    3:09-cr-00110       974  2012-10-02    2012-10-02  2012-03-13
# 1194            NaN       NaN  2011-08-19           NaN         NaN
# 2696  1:16-cr-20968       NaN  2016-12-22           NaN         NaN
# 3016  2:12-cr-20064        11  2012-03-01    2012-03-01  2012-03-01
# 393   1:06-cr-00111       657  2008-08-28    2008-08-28  2008-08-27
# 1512            NaN       NaN  2005-08-01           NaN         NaN
# 2505  1:08-cr-00367        17  2009-01-06    2009-01-06  2008-12-15
# 460   3:14-cr-00068        14  2014-04-30    2014-04-30  2014-04-30
# 1538  4:09-cr-00071        13  2009-02-12    2009-02-12  2009-02-11
# 1584  3:08-cr-00803        20  2008-12-23    2008-12-23  2008-12-08
# 502   3:03-cr-30144        11  2003-10-27    2003-10-27  2003-07-23
# 2814            NaN       NaN  2012-12-18           NaN         NaN
# 2772  2:13-cr-00001        31  2013-02-14    2013-02-14  2013-01-03
# 294   1:10-cr-00035         9  2010-03-02    2010-03-02  2010-02-04
# 2380  3:15-cr-00080       NaN  2017-01-10    2017-01-10  2015-05-20
# 144   1:10-cr-00375        20  2010-10-07    2010-10-07  2010-05-10
# 1563  3:12-cr-00137       NaN  2015-05-01    2015-05-01  2015-04-30
# 295             NaN       NaN  2006-10-01           NaN         NaN
# 1468  2:13-cr-00605        12  2013-11-07    2013-11-07  2013-11-07
# ...             ...       ...         ...           ...         ...
# 2713  3:08-cr-00085       170  2009-01-28    2009-01-28  2008-10-30
# 566   7:01-cr-00203        34  2002-01-28    2002-01-28  2001-08-27
# 1973  4:05-cr-00781       101  2006-03-28    2006-03-28  2005-10-17
# 2709  1:10-cr-20329        77  2010-12-06    2010-12-06  2010-12-06
# 2060  1:10-cr-00363       262  2012-07-23    2012-07-23  2012-02-02
# 2424  1:00-cr-00150         8  2001-04-20    2001-04-20  2000-12-01
# 1513  1:07-cr-00657       260  2010-12-15    2010-12-15  2010-05-11
# 278             NaN       NaN  2001-01-22           NaN         NaN
# 1082  3:00-cr-00039       109  2005-12-19    2005-12-19  2005-11-29
# 2425            NaN       NaN  1992-05-01           NaN         NaN
# 1601  4:10-cr-00274         5  2010-10-05    2010-10-05  2010-10-06
# 1003            NaN       NaN  2010-12-08           NaN         NaN
# 2430  4:05-cr-00643        14  2005-12-02    2005-12-02  2005-11-30
# 2697  6:10-mj-06004        35  2011-09-19    2011-09-19  2011-09-19
# 1213  2:02-cr-00485       404  2005-09-07    2005-09-07  2005-09-07
# 1518  8:10-cr-00212        29  2011-03-07    2011-03-07  2010-10-22
# 2437  1:07-cr-00657       264  2010-12-17    2010-12-17  2010-05-11
# 1597  3:05-cr-01631        16  2007-09-10    2007-09-10  2007-09-07
# 2688  1:11-cr-00269        26  2012-01-20    2012-01-20  2011-03-24
# 2441  2:07-cr-00583        13  2007-07-10    2007-07-10  2007-05-11
# 552             NaN       NaN  2013-03-13           NaN         NaN
# 551   3:07-cr-00514         9  2007-12-28    2007-12-28  2007-12-28
# 1604  5:00-cr-00098         5  2000-02-24    2000-02-24  2000-02-24
# 2718  3:16-cr-00010       NaN         NaN           NaN  2016-03-29
# 1195  6:08-cr-06019       229  2011-09-27    2011-09-27  2011-09-27
# 270   1:03-cr-00320        28  2005-09-26    2005-09-26  2005-01-27
# 2101  5:01-cr-00021       138  2002-09-13    2002-09-13  2001-12-19
# 254             NaN       NaN  1996-04-01           NaN         NaN
# 255   1:04-cr-00127        36  2006-03-31    2006-03-31  2005-10-14
# 2147            NaN       NaN  2008-10-23           NaN         NaN
# 1891  1:00-cr-10017        16  2000-02-02    2000-02-02  2000-01-13
# 2146  2:01-cr-00046        30  2002-01-02    2002-01-02  2001-04-11
# 2741  4:16-mj-00010       NaN  2016-12-06    2016-12-06  2016-11-30
# 2391  2:04-cr-00408        16  2004-08-02    2004-08-02  2004-08-03
# 2392  5:02-cr-00124       235  2004-02-20    2004-02-20  2002-04-02
# 2393  1:07-cr-00646         0  2009-07-31           NaN  2009-07-29
# 2737            NaN         0         NaN           NaN  1995-06-01
# 263   9:99-cr-08125       790  2000-08-23    2000-08-23  2000-05-30
# 583   2:01-cr-00164       217  2004-10-15    2004-10-15  2003-05-12
# 582   1:09-cr-20852       310  2011-01-24    2011-01-24  2010-10-01
# 2731  4:08-cr-00715         6  2008-12-17    2008-12-17  2008-12-17
# 2405  2:05-cr-00078         0  2010-02-09           NaN  2005-03-02
# 1010  2:03-cr-00203        44  2005-12-08    2005-12-08  2009-03-11
# 1200            NaN       NaN  2014-05-12           NaN         NaN
# 932   5:07-cr-00014        26  2007-10-10    2007-10-10  2007-06-06
# 1302  1:06-cr-00382       746  2009-02-04    2009-02-04  2008-08-15
# 2724  1:07-cr-20553       296  2008-05-23    2008-05-23  2008-05-23
# 1616            NaN       NaN  1996-10-01           NaN         NaN
# 269   3:08-cr-00266        16  2009-05-15    2009-05-15  2008-12-30
# 216   3:05-cr-01629       176  2007-09-10    2007-09-10  2007-09-10
#
#          TICKER US_PUBLIC_CO  ADDITIONAL_REGULATORY_FINE_OR_PAYMENT  \
# 307         NaN           No                                 400.00
# 309         NaN          Yes                                   0.00
# 2913        NaN          Yes                                    nan
# 1000        NaN           No                                    nan
# 753          CS          Yes                                   0.00
# 1454        NaN          Yes                                   0.00
# 2167        NaN          Yes                                    nan
# 1238        NaN          Yes                       1,256,000,000.00
# 2760         TM          Yes                                   0.00
# 1168        NaN          Yes                                    nan
# 636         NaN          Yes                                    nan
# 1154        NaN          Yes                                   0.00
# 164         NaN           No                                   0.00
# 75          NaN          Yes                         715,000,000.00
# 358         NaN          Yes                                    nan
# 61          NaN          Yes                         900,000,000.00
# 675         NaN           No                                   0.00
# 852          DB          Yes                                   0.00
# 957         NaN          Yes                         800,000,000.00
# 2031        NaN           No                                    nan
# 2815        NaN          Yes                         580,000,000.00
# 2331        NaN           No                                    nan
# 851         NaN          Yes                         553,633,153.00
# 1452        NaN          Yes                                    nan
# 2722        NaN          Yes                                    nan
# 335         NaN           No                                    nan
# 458         NaN          Yes                                    nan
# 959         NaN           No                                    nan
# 2687        NaN          Yes                                    nan
# 33          NaN           No                         500,000,000.00
# 2456        NaN          Yes                         370,392,977.00
# 55          NaN          Yes                                    nan
# 1194        NaN          Yes                         500,000,000.00
# 2696        NaN    Yes - ADR                                    nan
# 3016        NaN           No                                    nan
# 393         NaN           No                                    nan
# 1512        NaN           No                         328,000,000.00
# 2505        NaN          Yes                                    nan
# 460   ADR (TYO)          Yes                                   0.00
# 1538        NaN          Yes                                    nan
# 1584        NaN          Yes                                    nan
# 502         NaN           No                                    nan
# 2814        NaN          Yes                                   0.00
# 2772        NaN          Yes                                   0.00
# 294         NaN          Yes                                    nan
# 2380        NaN          Yes                                    nan
# 144         NaN          Yes                         225,000,000.00
# 1563        NaN           No                                    nan
# 295         NaN           No                         337,500,000.00
# 1468        NaN          Yes                                 125.00
# ...         ...          ...                                    ...
# 2713        NaN           No                                    nan
# 566         NaN           No                                    nan
# 1973        NaN           No                                    nan
# 2709        NaN           No                                   0.00
# 2060        NaN           No                                    nan
# 2424        NaN           No                                    nan
# 1513        NaN           No                                    nan
# 278         NaN          Yes                                   0.00
# 1082        NaN           No                                    nan
# 2425        NaN           No                                    nan
# 1601        NaN           No                                    nan
# 1003        NaN          Yes                                   0.00
# 2430        NaN           No                                    nan
# 2697        NaN           No                                   0.00
# 1213        NaN           No                                   0.00
# 1518        NaN           No                                    nan
# 2437        NaN           No                                    nan
# 1597        NaN           No                                   0.00
# 2688        NaN           No                                    nan
# 2441        NaN           No                                    nan
# 552         NaN           No                                    nan
# 551         NaN           No                                    nan
# 1604        NaN           No                                    nan
# 2718        NaN           No                                    nan
# 1195        NaN           No                                    nan
# 270         NaN           No                                    nan
# 2101        NaN           No                                    nan
# 254         NaN           No                                    nan
# 255         NaN           No                                    nan
# 2147        NaN          Yes                                   0.00
# 1891        NaN           No                                    nan
# 2146        NaN           No                                    nan
# 2741        NaN           No                                    nan
# 2391        NaN           No                                    nan
# 2392        NaN           No                                    nan
# 2393        NaN           No                                   0.00
# 2737        NaN           No                                    nan
# 263         NaN           No                                    nan
# 583         NaN           No                                    nan
# 582         NaN           No                                    nan
# 2731        NaN           No                                    nan
# 2405        NaN           No                                    nan
# 1010        NaN           No                                    nan
# 1200        NaN           No                                    nan
# 932         NaN           No                                    nan
# 1302        NaN           No                                    nan
# 2724        NaN           No                                    nan
# 1616        NaN           No                                    nan
# 269         NaN           No                                    nan
# 216         NaN           No                                    nan
#
#       COMMUNITY_SERVICE_OR_OTHER             FINE  FORFEITURE_DISGORGEMENT  \
# 307                         0.00   140,000,000.00         4,346,800,000.00
# 309             2,744,000,000.00 1,256,000,000.00                     0.00
# 2913                         nan 2,800,000,000.00                      nan
# 1000            2,000,000,000.00     3,000,000.00                      nan
# 753                         0.00 1,136,988,986.00                     0.00
# 1454                        0.00             0.00         1,700,000,000.00
# 2167                         nan 1,195,000,000.00                      nan
# 1238                         nan             0.00                      nan
# 2760                        0.00             0.00                     0.00
# 1168                         nan   956,814,400.00                      nan
# 636                          nan   925,000,000.00                     0.00
# 1154                        0.00             0.00           900,000,000.00
# 164                         0.00   772,290,000.00                     0.00
# 75                           nan             0.00                      nan
# 358                          nan   710,000,000.00                     0.00
# 61                           nan   500,000,000.00           198,500,000.00
# 675                         0.00    79,000,000.00           562,000,000.00
# 852                         0.00   625,000,000.00                     0.00
# 957                          nan   515,000,000.00           100,000,000.00
# 2031                         nan   612,000,000.00                      nan
# 2815                         nan             0.00                      nan
# 2331                         nan             0.00                      nan
# 851                          nan             0.00                      nan
# 1452                         nan   550,000,000.00                     0.00
# 2722                         nan              nan           546,000,000.00
# 335                          nan    81,000,000.00           214,000,000.00
# 458               442,837,735.00    94,893,800.00                     0.00
# 959                          nan   515,000,000.00                      nan
# 2687                         nan   512,788,345.00                      nan
# 33                  5,000,000.00             0.00                      nan
# 2456                         nan   130,000,000.00                      nan
# 55                           nan   500,000,000.00                      nan
# 1194                         nan             0.00                      nan
# ...
# 2697               nan                                                NaN
# 1213               nan                                                NaN
# 1518               nan                                                NaN
# 2437               nan                                                NaN
# 1597               nan                                                NaN
# 2688               nan                                                NaN
# 2441               nan                                                NaN
# 552                nan                                                NaN
# 551                nan                                                NaN
# 1604               nan                                                NaN
# 2718               nan                                                NaN
# 1195               nan                                                NaN
# 270                nan                                                NaN
# 2101               nan                                                NaN
# 254                nan                                                NaN
# 255                nan                                                NaN
# 2147              0.00                                                 No
# 1891               nan                                                NaN
# 2146               nan                                                NaN
# 2741               nan                                                NaN
# 2391               nan                                                NaN
# 2392               nan                                                NaN
# 2393               nan                                                NaN
# 2737               nan                                                NaN
# 263                nan                                                NaN
# 583                nan                                                NaN
# 582                nan                                                NaN
# 2731               nan                                                NaN
# 2405               nan                                                NaN
# 1010               nan                                                NaN
# 1200               nan                                                NaN
# 932                nan                                                NaN
# 1302               nan                                                NaN
# 2724               nan                                                NaN
# 1616               nan                                                NaN
# 269                nan                                                NaN
# 216                nan                                                NaN
#
#       AGMT_YEAR                                             SOURCE  \
# 307    2,015.00                                              PACER
# 309    2,013.00                                              PACER
# 2913   2,017.00                                              PACER
# 1000   2,005.00                                              PACER
# 753    2,014.00                                              PACER
# 1454   2,014.00                                                NaN
# 2167   2,007.00                                              PACER
# 1238   2,012.00                                                NaN
# 2760   2,014.00                                                NaN
# 1168   2,012.00                                              PACER
# 636    2,017.00                                                NaN
# 1154   2,015.00                                                NaN
# 164    2,015.00                                              PACER
# 75     2,005.00                                                NaN
# 358    2,017.00                                              PACER
# 61     2,012.00                                              PACER
# 675    2,015.00                                                NaN
# 852    2,015.00                                                NaN
# 957    2,009.00                                              PACER
# 2031   2,016.00  DOJ website:  https://www.justice.gov/usao-nj/...
# 2815   2,009.00                                                NaN
# 2331   2,002.00                                              PACER
# 851    2,010.00                                                NaN
# 1452   2,017.00                                                NaN
# 2722   2,017.00                                              PACER
# 335    2,016.00                                                NaN
# 458    2,017.00                                              PACER
# 959    2,009.00                                              PACER
# 2687   2,016.00  USDOJ website (see:  https://www.justice.gov/o...
# 33     2,010.00                                                NaN
# 2456   2,012.00                                                NaN
# 55     2,012.00                                              PACER
# 1194   2,011.00                                                NaN
# 2696   2,016.00  DOJ (see:  https://www.justice.gov/criminal-fr...
# 3016   2,012.00                                              PACER
# 393    2,008.00                                              PACER
# 1512   2,005.00                                                NaN
# 2505   2,009.00                                              PACER
# 460    2,014.00                                              PACER
# 1538   2,009.00                                              PACER
# 1584   2,008.00                                              PACER
# 502    2,003.00                                              PACER
# 2814   2,012.00                                                NaN
# 2772   2,013.00                                              PACER
# 294    2,010.00                                              PACER
# 2380   2,017.00                                              PACER
# 144    2,010.00                                              PACER
# 1563   2,015.00                                              PACER
# 295    2,006.00                                                NaN
# 1468   2,013.00                                              PACER
# ...         ...                                                ...
# 2713   2,009.00                                              PACER
# 566    2,002.00                                              PACER
# 1973   2,006.00                                              PACER
# 2709   2,010.00                                              PACER
# 2060   2,012.00                                              PACER
# 2424   2,001.00                                              PACER
# 1513   2,010.00                                              PACER
# 278    2,001.00                                                NaN
# 1082   2,005.00                                              PACER
# 2425   1,992.00                                                NaN
# 1601   2,010.00                                              PACER
# 1003   2,010.00                                                NaN
# 2430   2,005.00                                              PACER
# 2697   2,011.00                                              PACER
# 1213   2,005.00                                              PACER
# 1518   2,011.00                                              PACER
# 2437   2,010.00                                              PACER
# 1597   2,007.00                                              PACER
# 2688   2,012.00                                              PACER
# 2441   2,007.00                                              PACER
# 552    2,013.00                                       FOIA request
# 551    2,007.00                                              PACER
# 1604   2,000.00                                              PACER
# 2718        nan                                              PACER
# 1195   2,011.00                                              PACER
# 270    2,005.00                                              PACER
# 2101   2,002.00                                              PACER
# 254    1,996.00                                                NaN
# 255    2,006.00                                              PACER
# 2147   2,008.00                                                NaN
# 1891   2,000.00                                              PACER
# 2146   2,002.00                                              PACER
# 2741   2,016.00                                              PACER
# 2391   2,004.00                                              PACER
# 2392   2,004.00                                              PACER
# 2393   2,009.00                                              PACER
# 2737        nan                         Antitrust Division website
# 263    2,000.00                                              PACER
# 583    2,004.00                                              PACER
# 582    2,011.00                                              PACER
# 2731   2,008.00                                              PACER
# 2405   2,010.00                                              PACER
# 1010   2,005.00                                              PACER
# 1200   2,014.00                                                NaN
# 932    2,007.00                                              PACER
# 1302   2,009.00                                              PACER
# 2724   2,008.00                                              PACER
# 1616   1,996.00                                                NaN
# 269    2,009.00                                              PACER
# 216    2,007.00                                              PACER
#
#                                                   NOTES
# 307                                                 NaN
# 309                                                 NaN
# 2913                                                NaN
# 1000                                                NaN
# 753                                                 NaN
# 1454                                                NaN
# 2167                                                NaN
# 1238                                                NaN
# 2760                                                NaN
# 1168                                                NaN
# 636                                                 NaN
# 1154                                                NaN
# 164                                                 NaN
# 75                                                  NaN
# 358                                                 NaN
# 61                                                  NaN
# 675                                                 NaN
# 852                                                 NaN
# 957                                                 NaN
# 2031                                                NaN
# 2815                                                NaN
# 2331                                                NaN
# 851   Additional Civil Claims: fraud and breach of f...
# 1452                                                NaN
# 2722                                                NaN
# 335                                                 NaN
# 458        $442,837,735 payment to Government of Brazil
# 959                                                 NaN
# 2687                                                NaN
# 33    ABN Amro Holding NV (now known as Royal Bank o...
# 2456                                                NaN
# 55                                                  NaN
# 1194                                                NaN
# 2696                                                NaN
# 3016                                                NaN
# 393                                                 NaN
# 1512                                                NaN
# 2505                                                NaN
# 460                                                 NaN
# 1538                                                NaN
# 1584                                                NaN
# 502                                                 NaN
# 2814                                                NaN
# 2772                                                NaN
# 294                                                 NaN
# 2380                                                NaN
# 144                                                 NaN
# 1563                                                NaN
# 295   Securities Litigation information: http://www....
# 1468                                                NaN
# ...                                                 ...
# 2713                                                NaN
# 566                                                 NaN
# 1973                                                NaN
# 2709                                                NaN
# 2060                                                NaN
# 2424                                                NaN
# 1513                                                NaN
# 278                                                 NaN
# 1082                                                NaN
# 2425                                                NaN
# 1601                                                NaN
# 1003  Corporate Integrity Agreement found at: http:/...
# 2430                                                NaN
# 2697                                                NaN
# 1213                                                NaN
# 1518                                                NaN
# 2437                                                NaN
# 1597                                                NaN
# 2688                                                NaN
# 2441                  Forfeiture of van in lieu of fine
# 552                                                 NaN
# 551                                                 NaN
# 1604                                                NaN
# 2718             Plea agreement not available via PACER
# 1195                                                NaN
# 270                                                 NaN
# 2101                                                NaN
# 254                                                 NaN
# 255   "The Defendant Corporation shall be enjoined f...
# 2147                                                NaN
# 1891                                                NaN
# 2146                                                NaN
# 2741                                                NaN
# 2391                                                NaN
# 2392                           Dissolution - all assets
# 2393                                                NaN
# 2737                                                NaN
# 263                                                 NaN
# 583                                                 NaN
# 582                                                 NaN
# 2731                                                NaN
# 2405                                                NaN
# 1010                                                NaN
# 1200                                                NaN
# 932                                                 NaN
# 1302                                                NaN
# 2724                                                NaN
# 1616                                                NaN
# 269                                                 NaN
# 216                                                 NaN
#
# [3038 rows x 56 columns]

# %% [markdown]
# # Column selection
#
# We wanted to view all of those rows, but honestly that's a little silly. **We can't actually see the data we want!** Let's just select the ones we care about.
#
# ## Create a new dataframe that only includes the company name, disposition type, total payment, and date.

# %%
new_df= df[['COMPANY', 'DISPOSITION_TYPE', 'TOTAL_PAYMENT', 'DATE']]

# %% [markdown]
# ## Confirm it has 3038 rows and 5 columns

# %%
new_df.shape
# Out:
# (3038, 4)

# %% [markdown]
# ## Using this subset, extract the year into a separate column called `year`
#
# Your machine will complain. **Let's talk about that error.**

# %%
new_df['year'] = new_df.DATE.str.extract('(^\d{4})')
new_df.head()
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                                   COMPANY DISPOSITION_TYPE  TOTAL_PAYMENT  \
# 0  1st Union Transfer and Telegraph, Inc.             plea         272734
# 1                3D Poultry Loading, Inc.             plea          24000
# 2                         3rd & Bell, LLC             plea             50
# 3                          41 Market Inc.             plea          14640
# 4                            45,000, Inc.             plea          27500
#
#          DATE  year
# 0  2003-06-17  2003
# 1  2005-01-25  2005
# 2  2014-11-21  2014
# 3  2006-07-05  2006
# 4  2005-06-03  2005

# %% [markdown]
# ## Make the 'year' column an integer.
#
# Or at least *try*, then turn it into a float. Why did one work but the other didn't?

# %%
new_df.year = new_df.year.astype(float)
new_df.head()
# Out:
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
#                                   COMPANY DISPOSITION_TYPE  TOTAL_PAYMENT  \
# 0  1st Union Transfer and Telegraph, Inc.             plea         272734
# 1                3D Poultry Loading, Inc.             plea          24000
# 2                         3rd & Bell, LLC             plea             50
# 3                          41 Market Inc.             plea          14640
# 4                            45,000, Inc.             plea          27500
#
#          DATE     year
# 0  2003-06-17 2,003.00
# 1  2005-01-25 2,005.00
# 2  2014-11-21 2,014.00
# 3  2006-07-05 2,006.00
# 4  2005-06-03 2,005.00

# %% [markdown]
# ## Make a histogram of cases over the years

# %%
new_df.year.hist()

# %% [markdown]
# ## What was the total amount paid across all cases each year?

# %%
new_df.groupby('year')['TOTAL_PAYMENT'].sum().sort_values(ascending = False)
# Out:
# year
# 2,015.00    9844845643
# 2,013.00    7724920476
# 2,014.00    7062535053
# 2,017.00    6866002335
# 2,012.00    6696816915
# 2,010.00    4745389066
# 2,005.00    4210235461
# 2,009.00    4090513821
# 2,016.00    3808529923
# 2,007.00    3034830498
# 2,011.00    2957950912
# 2,008.00    2729966187
# 2,004.00    1637537063
# 2,006.00    1201775794
# 2,003.00     911162220
# 2,002.00     829424749
# 2,001.00     761777886
# 2,000.00     278206161
# 1,999.00             0
# 1,998.00             0
# 1,996.00             0
# 1,994.00             0
# 1,993.00             0
# 1,992.00             0
# Name: TOTAL_PAYMENT, dtype: int64

# %% [markdown]
# ## Graph it!

# %%
new_df.groupby('year')['TOTAL_PAYMENT'].sum().sort_values(ascending = False).plot(kind='bar')

# %% [markdown]
# # Cleaning up a column
#
# Take a look at **AGREEMENT_REQUIRED_NEW_POSITIONS** in your **ORIGINAL DATAFRAME**. How many times does it have a value in it?
#
# - Tip: There are a few ways to do this. Maybe you want to ask for an easy one!

# %%
df['AGREEMENT_REQUIRED_NEW_POSITIONS'].value_counts().sum()
# Out:
# 261

# %% [markdown]
# ### What are the top 5 responses for `AGREEMENT_REQUIRED_NEW_POSITIONS`?

# %%
df['AGREEMENT_REQUIRED_NEW_POSITIONS'].value_counts().head(5)
# Out:
# No                                                                                       163
# Yes; Assignment one or more senior officers to compliance, with reporting obligations     46
# Yes; Chief Compliance Officer                                                              6
# Yes; Compliance Officer                                                                    6
# Yes; Compliance officer                                                                    3
# Name: AGREEMENT_REQUIRED_NEW_POSITIONS, dtype: int64

# %% [markdown]
# ## That looks messy.
#
# ### HOLD ON, time to learn something
#
# **There are a few ways to do the next question**, but a couple popular methods will have pandas yell at you. You might want to try this new thing called `loc`! **It is used to update a column in a row based on a condition.**
#
# ```
# df.loc[df.country == 'Angola', "continent"] = "Africa"
# ```
#
# This updates the `continent` column to be `Africa` for every row where `df.country == 'Angola'`. You CANNOT do the following, which is probably what you've wanted to do:
#
# ```
# df[df.country == 'Angola']['continent'] = 'Africa'
# ```
#
# And now you know.
#
# ## Start to this up by creating a new column called `required_new_position`.
#
# This column should be `True` if a new position was required, `False` if a new position was not required, and `NaN` if it's unknown.
#
# - Tip: You should use `.str.contains`
# - Tip: Do you know how to say "at the start of a line" using regex?
# - Tip: We've talked about how to avoid `cannot index with vector containing NA / NaN values` but if you get it feel free to write it on the board

# %%
df.loc[df.AGREEMENT_REQUIRED_NEW_POSITIONS == 'No', "required_new_position"] = False

# %%
df.loc[df.AGREEMENT_REQUIRED_NEW_POSITIONS.str.contains('^[Yy]es;', na = False), "required_new_position"] = True

# %%
df[df.required_new_position == True].head(5)
# Out:
#     REC_ID                                            COMPANY  \
# 23       2  AB Volvo [on behalf of itself and subsidiaries...
# 44       6                                        AGA Medical
# 45       7                                         AGCO Corp.
# 63     742                                       Academi, LLC
# 74     755                        Adams Thermal Systems, Inc.
#
#                   DISPOSITION_TYPE                     PRIMARY_CRIME_CODE  \
# 23  deferred prosecution agreement                                   FCPA
# 44  deferred prosecution agreement                                   FCPA
# 45  deferred prosecution agreement                                   FCPA
# 63  deferred prosecution agreement                        Import / Export
# 74  deferred prosecution agreement  OSHA / Workplace Safety / Mine Safety
#
#    SWISS_BANK_PROGRAM                                       USAO  \
# 23                 No  USDOJ - Criminal Division - Fraud Section
# 44                 No  USDOJ - Criminal Division - Fraud Section
# 45                 No  USDOJ - Criminal Division - Fraud Section
# 63                 No          North Carolina - Eastern District
# 74                 No                               South Dakota
#
#           COUNTRY FINANCIAL_INSTITUTION CASE_NAME CASE_ID DOCKET_NO  \
# 23         Sweden                    No       NaN     NaN       NaN
# 44  United States                    No       NaN     NaN       NaN
# 45  United States                    No       NaN     NaN       NaN
# 63  United States                    No       NaN     NaN       NaN
# 74  United States                    No       NaN     NaN       NaN
#
#           DATE JUDGMENT_DATE PLEA_DATE TICKER US_PUBLIC_CO  \
# 23  2008-03-20           NaN       NaN    NaN           No
# 44  2008-06-03           NaN       NaN    NaN           No
# 45  2009-09-29           NaN       NaN    NaN          Yes
# 63  2012-08-07           NaN       NaN    NaN           No
# 74  2013-09-05           NaN       NaN    NaN           No
#
#     ADDITIONAL_REGULATORY_FINE_OR_PAYMENT  COMMUNITY_SERVICE_OR_OTHER  \
# 23                                   0.00                         nan
# 44                                   0.00                         nan
# 45                                   0.00                         nan
# 63                                   0.00                         nan
# 74                             435,000.00                         nan
#
#            FINE  FORFEITURE_DISGORGEMENT  PROBATION_LENGTH  RESTITUTION  \
# 23 7,000,000.00                      nan             36.00          nan
# 44 2,000,000.00                      nan             36.00          nan
# 45 1,600,000.00                      nan             36.00          nan
# 63 7,500,000.00                      nan             36.00          nan
# 74   450,000.00                      nan             36.00   450,000.00
#
#     TOTAL_PAYMENT ACCEPTS_RESPONSIBILITY  \
# 23        7000000                    Yes
# 44        2000000                    Yes
# 45        1600000                    Yes
# 63        7500000                    Yes
# 74         900000                    Yes
#
#                      AGREEMENT_REQUIRED_NEW_POSITIONS  \
# 23  Yes; Assigning "one or more senior corporate o...
# 44  Yes; Assigning one or more senior corporate of...
# 45  Yes; Assigning one or more senior corporate of...
# 63  Yes; Hired fulltime Director, Export Complianc...
# 74  Yes; More safety and health department employe...
#
#        AGREEMENT_REQUIRED_OUTSIDE_AUDITORS_OR_EXPERTS  \
# 23                                                 No
# 44                                                 No
# 45                                                 No
# 63  Yes; Third party auditors to conduct annual au...
# 74   Yes; Review Department of Labor compliance terms
#
#                              CITATION_AND_DESCRIPTION  \
# 23  Government of Iraq, in civil suit naming 93 de...
# 44  (contract case with Middle Eastern supplier: H...
# 45                                                NaN
# 63                                                NaN
# 74                                                NaN
#
#    CIVIL_JUDGMENT_OR_SETTLEMENT  \
# 23                           No
# 44                           No
# 45                           No
# 63                          NaN
# 74                          NaN
#
#                        COMPLIANCE_PROGRAM_DESCRIPTION  \
# 23  System of internal accounting controls, implem...
# 44  System of internal accounting controls; implem...
# 45  Implement compliance and ethics program; enhan...
# 63  Conduct annual audits to monitor compliance wi...
# 74  Third party to audit terms of agreement, which...
#
#    COMPLIANCE_PROGRAM_REQUIRED_BY_AGREEMENT  \
# 23                                      Yes
# 44                                      Yes
# 45                                      Yes
# 63                                      Yes
# 74                                      Yes
#
#                     COMPLIANCE_REQUIRED_BY_REGULATORS  \
# 23  Yes; Must use qualified independent third part...
# 44                                                NaN
# 45                                                 No
# 63  Yes; Xe Services LLC (predecessor) entered int...
# 74                                    Yes; DOL (OSHA)
#
#                                            CRIME_DESC DESCRIPTION_OF_PAYMENTS  \
# 23                                   FCPA; wire fraud                     NaN
# 44                                               FCPA                     NaN
# 45  Wire fraud; falsification of books and records...                     NaN
# 63  Export violations (Arms Export Control Act; In...                     NaN
# 74                                               OSHA                     NaN
#
#    DOES_AGREEMENT_DISCUSS_REASONS_OR_RELEVENT_CONSIDERATIONS_FOR_LENIENCY  \
# 23  Yes; including thorough investigation, coopera...
# 44  Yes; including timely disclosure, cooperation,...
# 45                                               Yes.
# 63                                                NaN
# 74  Yes; acceptance of responsibility, entry into ...
#
#    DOJ_CAN_UNILATERALLY_TERMINATE FINE_CALCULATION_INCLUDED  \
# 23                            Yes                        No
# 44                            Yes                        No
# 45                            Yes                        No
# 63                            Yes                        No
# 74                            Yes                        No
#
#                                      FINE_DESCRIPTION INDEP_MONITOR_REQUIRED  \
# 23                                          $7M fine.                     No
# 44                                          $2M fine.                    Yes
# 45                                         $1.6M fine                     No
# 63  $7.5M fine; $42M civil settlement with Departm...                    Yes
# 74  Agreement with USAO sets out $1.35 million in ...                     No
#
#    MUST_COMPORT_WITH_USSG_OR_AUDIT_COMPLIANCE OTHER_AGREEMENT  \
# 23                                         No             NaN
# 44                                         No             NaN
# 45                      Yes; Periodic testing             NaN
# 63                         Yes; Annual audits   Consent Agmt.
# 74           Yes; Periodic review and testing             NaN
#
#           OTHER_AGREEMENT_REQUIRED_GOVERNANCE_CHANGES  \
# 23                                                 No
# 44                                                 No
# 45                                                 No
# 63                                                 No
# 74  Yes; Safety and health departments to report d...
#
#    OTHER_COMPLIANCE_OFFICER_OR_CONSULTANT_REQUIRED PARALLEL_CIVIL_SUIT  \
# 23                                              No                 Yes
# 44                                              No                 Yes
# 45                                              No                  No
# 63                                             Yes                  No
# 74                                              No                 NaN
#
#        PARALLEL_REGULATORY_ACTION_OR_LOCAL_PROSECUTOR  \
# 23                                           Yes; SEC
# 44                                                NaN
# 45                                           Yes; SEC
# 63                           Yes; Department of State
# 74  Yes; OSHA ($435,000), two pending administrati...
#
#    PRE_AGREEMENT_COMPLIANCE  \
# 23                      Yes
# 44                      Yes
# 45                      Yes
# 63                      Yes
# 74                       No
#
#                  PRE_AGREEMENT_COMPLIANCE_DESCRIPTION  \
# 23  Yes; Implementation of compliance and ethics p...
# 44  Yes; Internal investigation with results repor...
# 45  Yes; Internal investigation; remedial actions ...
# 63  Yes; Acknowledged responsibility; established ...
# 74                                     No; None cited
#
#                                        PRIVACY_WAIVER  \
# 23  No; But withholding on grounds of privilege sh...
# 44  No; But withholding on grounds of privilege sh...
# 45                                                 No
# 63  No; But assertion of privilege will be noted b...
# 74                                                 No
#
#     REGULATORY_DISGORGEMENT_RESTITUTION_FORFEITURE  REGULATORY_FINE  \
# 23                                    8,603,000.00     4,000,000.00
# 44                                             nan              nan
# 45                                   15,907,000.00     2,400,000.00
# 63                                            0.00    42,000,000.00
# 74                                            0.00       435,000.00
#
#                                            REG_AGENCY STATEMENT_OF_FACTS  \
# 23                                               None                Yes
# 44                                               None                Yes
# 45  Securities and Exchange Commission (SEC) (sepa...                Yes
# 63  Dept. of State; Dept. of Justice - National Se...                Yes
# 74                                     Dept. of Labor                Yes
#
#     TOTAL_REGULATORY UNRELATED_TERMS  AGMT_YEAR SOURCE  \
# 23     12,603,000.00              No   2,008.00    NaN
# 44              0.00              No   2,008.00    NaN
# 45     18,307,000.00              No   2,009.00    NaN
# 63     42,000,000.00              No   2,012.00    NaN
# 74        435,000.00             NaN   2,013.00    NaN
#
#                                                 NOTES required_new_position
# 23          Subsidiaries located in France and Sweden                  True
# 44                                                NaN                  True
# 45  AGCO also paid $630,000 in disgorgement of pro...                  True
# 63  This is not a parallel civil action but someth...                  True
# 74                                                NaN                  True

# %% [markdown]
# ### Confirm that your new column has 163 `True` values and 98 `False` values

# %%
# Typo - asking for 163 False and 96 True values
df.required_new_position.value_counts()
# Out:
# False    163
# True      96
# Name: required_new_position, dtype: int64

# %% [markdown]
# ## Extract the position name into a new column called `new_position`

# %%
df['new_position'] = df.AGREEMENT_REQUIRED_NEW_POSITIONS.str.extract('^[Yy]es; (.*)')
df.head()
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.
#    REC_ID                                 COMPANY DISPOSITION_TYPE  \
# 0     138  1st Union Transfer and Telegraph, Inc.             plea
# 1     139                3D Poultry Loading, Inc.             plea
# 2    2529                         3rd & Bell, LLC             plea
# 3     822                          41 Market Inc.             plea
# 4     140                            45,000, Inc.             plea
#
#                          PRIMARY_CRIME_CODE SWISS_BANK_PROGRAM  \
# 0                          Money Laundering                NaN
# 1                               Immigration                NaN
# 2                               Immigration                NaN
# 3  Controlled substances / Drugs / Meth Act                NaN
# 4                             Environmental                NaN
#
#                           USAO        COUNTRY FINANCIAL_INSTITUTION  \
# 0  Virginia - Eastern District  United States                   Yes
# 1  Arkansas - Western District  United States                    No
# 2                      Arizona  United States                    No
# 3  Georgia - Northern District  United States                    No
# 4  Louisiana - Middle District  United States                    No
#
#                                       CASE_NAME        CASE_ID DOCKET_NO  \
# 0                     USA v. 1st Union Transfer  4:03-cr-00024         8
# 1                     USA v. 3D Poultry Loading  2:04-cr-20061         7
# 2  USA v. Danny's Management Services LLC et al  2:13-cr-01143       510
# 3                         USA v. 41 Market Inc.  4:06-cr-00023        11
# 4                              USA v. 45000 Inc  3:04-cr-00180        17
#
#          DATE JUDGMENT_DATE   PLEA_DATE TICKER US_PUBLIC_CO  \
# 0  2003-06-17    2003-06-17  2003-02-28    NaN           No
# 1  2005-01-25    2005-01-25  2004-09-30    NaN           No
# 2  2014-11-21    2014-11-21  2014-11-20    NaN           No
# 3  2006-07-05    2006-07-05  2006-03-16    NaN           No
# 4  2005-06-03    2005-06-03  2004-11-22    NaN           No
#
#    ADDITIONAL_REGULATORY_FINE_OR_PAYMENT  COMMUNITY_SERVICE_OR_OTHER  \
# 0                                    nan                         nan
# 1                                    nan                         nan
# 2                                   0.00                        0.00
# 3                                    nan                         nan
# 4                                    nan                         nan
#
#        FINE  FORFEITURE_DISGORGEMENT  PROBATION_LENGTH  RESTITUTION  \
# 0      0.00               272,734.00             12.00          nan
# 1 24,000.00                      nan             36.00          nan
# 2     50.00                     0.00              0.00         0.00
# 3 14,640.00                      nan             36.00          nan
# 4 25,000.00                      nan              0.00     2,500.00
#
#    TOTAL_PAYMENT ACCEPTS_RESPONSIBILITY AGREEMENT_REQUIRED_NEW_POSITIONS  \
# 0         272734                    NaN                              NaN
# 1          24000                    NaN                              NaN
# 2             50                    NaN                              NaN
# 3          14640                    NaN                              NaN
# 4          27500                    NaN                              NaN
#
#   AGREEMENT_REQUIRED_OUTSIDE_AUDITORS_OR_EXPERTS CITATION_AND_DESCRIPTION  \
# 0                                            NaN                      NaN
# 1                                            NaN                      NaN
# 2                                            NaN                      NaN
# 3                                            NaN                      NaN
# 4                                            NaN                      NaN
#
#   CIVIL_JUDGMENT_OR_SETTLEMENT COMPLIANCE_PROGRAM_DESCRIPTION  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
#
#   COMPLIANCE_PROGRAM_REQUIRED_BY_AGREEMENT COMPLIANCE_REQUIRED_BY_REGULATORS  \
# 0                                      NaN                               NaN
# 1                                      NaN                               NaN
# 2                                      NaN                               NaN
# 3                                      NaN                               NaN
# 4                                      NaN                               NaN
#
#   CRIME_DESC DESCRIPTION_OF_PAYMENTS  \
# 0        NaN                     NaN
# 1        NaN                     NaN
# 2        NaN                     NaN
# 3        NaN                     NaN
# 4        NaN                     NaN
#
#   DOES_AGREEMENT_DISCUSS_REASONS_OR_RELEVENT_CONSIDERATIONS_FOR_LENIENCY  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   DOJ_CAN_UNILATERALLY_TERMINATE FINE_CALCULATION_INCLUDED FINE_DESCRIPTION  \
# 0                            NaN                       NaN              NaN
# 1                            NaN                       NaN              NaN
# 2                            NaN                       NaN              NaN
# 3                            NaN                       NaN              NaN
# 4                            NaN                       NaN              NaN
#
#   INDEP_MONITOR_REQUIRED MUST_COMPORT_WITH_USSG_OR_AUDIT_COMPLIANCE  \
# 0                    NaN                                        NaN
# 1                    NaN                                        NaN
# 2                    NaN                                        NaN
# 3                    NaN                                        NaN
# 4                    NaN                                        NaN
#
#   OTHER_AGREEMENT OTHER_AGREEMENT_REQUIRED_GOVERNANCE_CHANGES  \
# 0             NaN                                         NaN
# 1             NaN                                         NaN
# 2             NaN                                         NaN
# 3             NaN                                         NaN
# 4             NaN                                         NaN
#
#   OTHER_COMPLIANCE_OFFICER_OR_CONSULTANT_REQUIRED PARALLEL_CIVIL_SUIT  \
# 0                                             NaN                 NaN
# 1                                             NaN                 NaN
# 2                                             NaN                 NaN
# 3                                             NaN                 NaN
# 4                                             NaN                 NaN
#
#   PARALLEL_REGULATORY_ACTION_OR_LOCAL_PROSECUTOR PRE_AGREEMENT_COMPLIANCE  \
# 0                                            NaN                      NaN
# 1                                            NaN                      NaN
# 2                                            NaN                      NaN
# 3                                            NaN                      NaN
# 4                                            NaN                      NaN
#
#   PRE_AGREEMENT_COMPLIANCE_DESCRIPTION PRIVACY_WAIVER  \
# 0                                  NaN            NaN
# 1                                  NaN            NaN
# 2                                  NaN            NaN
# 3                                  NaN            NaN
# 4                                  NaN            NaN
#
#    REGULATORY_DISGORGEMENT_RESTITUTION_FORFEITURE  REGULATORY_FINE REG_AGENCY  \
# 0                                             nan              nan        NaN
# 1                                             nan              nan        NaN
# 2                                             nan              nan        NaN
# 3                                             nan              nan        NaN
# 4                                             nan              nan        NaN
#
#   STATEMENT_OF_FACTS  TOTAL_REGULATORY UNRELATED_TERMS  AGMT_YEAR SOURCE  \
# 0                NaN               nan             NaN   2,003.00  PACER
# 1                NaN               nan             NaN   2,005.00  PACER
# 2                NaN               nan             NaN   2,014.00  PACER
# 3                NaN               nan             NaN   2,006.00  PACER
# 4                NaN               nan             NaN   2,005.00  PACER
#
#   NOTES required_new_position new_position
# 0   NaN                   NaN          NaN
# 1   NaN                   NaN          NaN
# 2   NaN                   NaN          NaN
# 3   NaN                   NaN          NaN
# 4   NaN                   NaN          NaN

# %% [markdown]
# ## Make sure you extracted correctly
#
# The line below should show at least SIX rows. If it doesn't show any rows, something went wrong!
#
# - Tip: A `.value_counts()` might look okay, even though something is a little off.

# %%
df[df.new_position == "Compliance Officer"]
# Out:
#       REC_ID                                            COMPANY  \
# 441      663                                         Boeing Co.
# 664      587                               Columbia Farms, Inc.
# 1063      51  Fisher Sand & Gravel / General Steel (subsid.)...
# 1657     609                                 Louis Berger Group
# 1661     610                              Love Irrigation, Inc.
# 3005     645                    Wright Medical Technology, Inc.
#
#                     DISPOSITION_TYPE PRIMARY_CRIME_CODE SWISS_BANK_PROGRAM  \
# 441        non-prosecution agreement    Fraud - General                 No
# 664   deferred prosecution agreement        Immigration                 No
# 1063  deferred prosecution agreement        Fraud - Tax                 No
# 1657  deferred prosecution agreement    Fraud - General                 No
# 1661  deferred prosecution agreement        Immigration                 No
# 3005  deferred prosecution agreement          Kickbacks                 No
#
#                                                    USAO        COUNTRY  \
# 441   California - Central District,Virginia - Easte...  United States
# 664                                      South Carolina  United States
# 1063                               USDOJ - Tax Division  United States
# 1657                                         New Jersey  United States
# 1661                    Mississippi - Southern District  United States
# 3005                                         New Jersey  United States
#
#      FINANCIAL_INSTITUTION CASE_NAME CASE_ID DOCKET_NO        DATE  \
# 441                     No       NaN     NaN       NaN  2006-06-01
# 664                     No       NaN     NaN       NaN  2009-11-03
# 1063                    No       NaN     NaN       NaN  2009-04-29
# 1657                   Yes       NaN     NaN       NaN  2010-11-05
# 1661                    No       NaN     NaN       NaN  2012-05-22
# 3005                    No       NaN     NaN       NaN  2010-10-01
#
#      JUDGMENT_DATE PLEA_DATE TICKER US_PUBLIC_CO  \
# 441            NaN       NaN    NaN          Yes
# 664            NaN       NaN    NaN           No
# 1063           NaN       NaN    NaN           No
# 1657           NaN       NaN    NaN           No
# 1661           NaN       NaN    NaN           No
# 3005           NaN       NaN    NaN          Yes
#
#       ADDITIONAL_REGULATORY_FINE_OR_PAYMENT  COMMUNITY_SERVICE_OR_OTHER  \
# 441                                    0.00                         nan
# 664                            1,500,000.00                         nan
# 1063                             668,141.00                         nan
# 1657                                   0.00                         nan
# 1661                             390,110.00                         nan
# 3005                                   0.00                         nan
#
#               FINE  FORFEITURE_DISGORGEMENT  PROBATION_LENGTH  RESTITUTION  \
# 441  50,000,000.00                      nan             24.00          nan
# 664           0.00                      nan             24.00 1,500,000.00
# 1063    500,000.00                      nan             30.00   668,141.00
# 1657 18,700,000.00                      nan             24.00          nan
# 1661    125,000.00                      nan             36.00   390,110.00
# 3005          0.00                      nan             12.00          nan
#
#       TOTAL_PAYMENT ACCEPTS_RESPONSIBILITY AGREEMENT_REQUIRED_NEW_POSITIONS  \
# 441        50000000                    Yes          Yes; Compliance Officer
# 664         1500000                    Yes          Yes; Compliance Officer
# 1063        1168141                    Yes          Yes; Compliance Officer
# 1657       18700000                    Yes          Yes; Compliance Officer
# 1661         515110                    Yes          Yes; Compliance Officer
# 3005              0                    Yes          Yes; Compliance Officer
#
#      AGREEMENT_REQUIRED_OUTSIDE_AUDITORS_OR_EXPERTS  \
# 441                                              No
# 664                                              No
# 1063                                             No
# 1657                                             No
# 1661                                            NaN
# 3005                                             No
#
#                                CITATION_AND_DESCRIPTION  \
# 441   Yes (RICO - possession of competitor documents...
# 664                                                 NaN
# 1063                                                NaN
# 1657                                                NaN
# 1661                                                NaN
# 3005                                                NaN
#
#      CIVIL_JUDGMENT_OR_SETTLEMENT  \
# 441                           NaN
# 664                           NaN
# 1063                          NaN
# 1657                          NaN
# 1661                          NaN
# 3005                          NaN
#
#                          COMPLIANCE_PROGRAM_DESCRIPTION  \
# 441   Training; discipline; prohibiting retaliation;...
# 664   Designation of compliance officer; ICE reporti...
# 1063  Designate Compliance Officer to oversee implem...
# 1657  Complaince, training, hotline, new compliance ...
# 1661  Use of e-verify, training, designate complianc...
# 3005  Compliance program; training; hotline; needs a...
#
#      COMPLIANCE_PROGRAM_REQUIRED_BY_AGREEMENT  \
# 441                                       Yes
# 664                                       Yes
# 1063                                      Yes
# 1657                                      Yes
# 1661                                      Yes
# 3005                                      Yes
#
#                       COMPLIANCE_REQUIRED_BY_REGULATORS  \
# 441   Yes; Interim Agreement with Air Force: maintai...
# 664                                                 NaN
# 1063                                                Yes
# 1657                                                 No
# 1661                                                 No
# 3005  Yes; Civil Settlement Agreement with civil div...
#
#                                              CRIME_DESC  \
# 441   Federal procurement fraud, conflict of interes...
# 664                       Immigration, false statements
# 1063                                          Tax fraud
# 1657                               Major Frauds Statute
# 1661    Immigration - harboring, employment, conspiracy
# 3005                              Anti-Kickback Statute
#
#      DESCRIPTION_OF_PAYMENTS  \
# 441                      NaN
# 664                      NaN
# 1063                     NaN
# 1657                     NaN
# 1661                     NaN
# 3005                     NaN
#
#      DOES_AGREEMENT_DISCUSS_REASONS_OR_RELEVENT_CONSIDERATIONS_FOR_LENIENCY  \
# 441   Yes; in exchange for good faith performance of...
# 664   Yes; acceptance of responsibility, compliance,...
# 1063  Yes; acceptance of responsibility, cooperation...
# 1657  Yes; acceptance of responsibility, cooperation...
# 1661  Yes; acceptance of responsibility, cooperation...
# 3005  Yes; remediation, acknowledging responsibility...
#
#                          DOJ_CAN_UNILATERALLY_TERMINATE  \
# 441   No; But "conduct by a Boeing employee classifi...
# 664                                                 Yes
# 1063                                                Yes
# 1657                                                Yes
# 1661                                                Yes
# 3005                                     Yes; If breach
#
#                 FINE_CALCULATION_INCLUDED  \
# 441                                    No
# 664                                    No
# 1063                                   No
# 1657                                   No
# 1661  Yes; Bottom end of Guidelines range
# 3005                                   No
#
#                                        FINE_DESCRIPTION  \
# 441   $50M penalty, $565M civil settlement; $1.9M to...
# 664                                               $1.5M
# 1063  $668,141 restitution for unpaid lax liability;...
# 1657                                                NaN
# 1661                                         $1 million
# 3005  $7.9 million to HHS-OIG, as part of joint sett...
#
#      INDEP_MONITOR_REQUIRED  \
# 441                     Yes
# 664                      No
# 1063                     No
# 1657                    Yes
# 1661                     No
# 3005                    Yes
#
#              MUST_COMPORT_WITH_USSG_OR_AUDIT_COMPLIANCE       OTHER_AGREEMENT  \
# 441        Yes; Periodic auditing of compliance program  Interim Admin. Agmt.
# 664   Yes; Use of e-Verify program, annual review of...                   NaN
# 1063  Yes; Compliance Officer must evaluate periodic...                   NaN
# 1657                                                 No                   NaN
# 1661                                                 No                   NaN
# 3005                                                 No                   NaN
#
#      OTHER_AGREEMENT_REQUIRED_GOVERNANCE_CHANGES  \
# 441                                           No
# 664                                           No
# 1063                                          No
# 1657                Yes; New obligations of CFO)
# 1661                                         NaN
# 3005                                          No
#
#      OTHER_COMPLIANCE_OFFICER_OR_CONSULTANT_REQUIRED  \
# 441                                              Yes
# 664                                               No
# 1063                                              No
# 1657                                             Yes
# 1661                                             Yes
# 3005                                             Yes
#
#                                     PARALLEL_CIVIL_SUIT  \
# 441                                                 Yes
# 664                                                  No
# 1063                                                 No
# 1657                                                 No
# 1661                                                 No
# 3005  No; Implant lawsuits relate to design of produ...
#
#      PARALLEL_REGULATORY_ACTION_OR_LOCAL_PROSECUTOR PRE_AGREEMENT_COMPLIANCE  \
# 441                                             Yes                      Yes
# 664                                             NaN                      Yes
# 1063                                            NaN                      Yes
# 1657                                             No                      Yes
# 1661                                       Yes; SEC                       No
# 3005                                   Yes; HHS-OIG                      Yes
#
#                    PRE_AGREEMENT_COMPLIANCE_DESCRIPTION PRIVACY_WAIVER  \
# 441   Yes; Changes to ethics and compliance program;...             No
# 664   Yes; Cites significant remedial actions taken ...             No
# 1063             Yes; Drafted a Code of Business Ethics             No
# 1657  Yes; "extensive reforms and remedial measures"...             No
# 1661                                                 No             No
# 3005  Yes; Described new policies, new Chief Complia...             No
#
#       REGULATORY_DISGORGEMENT_RESTITUTION_FORFEITURE  REGULATORY_FINE  \
# 441                                     1,900,000.00   595,000,000.00
# 664                                              nan              nan
# 1063                                             nan              nan
# 1657                                             nan              nan
# 1661                                            0.00     1,500,000.00
# 3005                                            0.00     7,900,000.00
#
#                                              REG_AGENCY STATEMENT_OF_FACTS  \
# 441   National Aeronautics and Space Administration ...                Yes
# 664   Dept. of Homeland Security;Dept. of Homeland S...                Yes
# 1063  Dept. of the Treasury - Internal Revenue Servi...                Yes
# 1657  Dept. of Justice - Civil Division - Fraud Sect...                Yes
# 1661  Dept. of Homeland Security - Immigration & Cus...                Yes
# 3005  U.S. Postal Inspection Service (USPIS); Dept. ...                 No
#
#       TOTAL_REGULATORY UNRELATED_TERMS  AGMT_YEAR SOURCE  \
# 441     596,900,000.00              No   2,006.00    NaN
# 664               0.00              No   2,009.00    NaN
# 1063              0.00              No   2,009.00    NaN
# 1657              0.00              No   2,010.00    NaN
# 1661      1,500,000.00              No   2,012.00    NaN
# 3005      7,900,000.00              No   2,010.00    NaN
#
#                                                   NOTES required_new_position  \
# 441   Information regarding the Interim Agreement: h...                  True
# 664                                                 NaN                  True
# 1063                                                NaN                  True
# 1657                                                NaN                  True
# 1661                                                NaN                  True
# 3005                                                NaN                  True
#
#             new_position
# 441   Compliance Officer
# 664   Compliance Officer
# 1063  Compliance Officer
# 1657  Compliance Officer
# 1661  Compliance Officer
# 3005  Compliance Officer

# %% [markdown]
# ## Find all cases that required a compliance officer
#
# That one above only gives us six. We want more! **Find at least 23 cases that required the creation of a compliance officer.**
#
# - Tip: Regular expressions might be your friend here
# - Tip: If you get an error about **new_position** not being found, change your code from when you created the column from `df.new_position = ...` to `df['new_position'] = ...`

# %%
df[df.new_position.str.contains('Compliance Officer', na = False)]['new_position'].value_counts()
# Out:
# Compliance Officer                                                                                                                                                                            6
# Chief Compliance Officer                                                                                                                                                                      6
# Retaining full time Chief Compliance Officer; assignment one or more senior officers to compliance, with reporting obligations                                                                1
# Expanded compliance department, compliance officer, established Research Committee, Compliance Officer and Vide President and Corporate Compliance Officer with set responsibilities          1
# Independent Chief Compliance Officer                                                                                                                                                          1
# Two new independent directors to Board, establish Compliance Committee, Disclosure Committee, hire five new internal auditors, new Chief Compliance Officer, reorganize Finance Department    1
# Appoint Chief Compliance Officer as member of Board, create Office of the Chief Compliance Officer                                                                                            1
# Compliance Officer, create Audit Committee, Nomination Committee, Compensation Commitee                                                                                                       1
# Create new Ethics and Compliance Officer, full-time auditor posittion, new liaison position                                                                                                   1
# Full time Compliance Officer                                                                                                                                                                  1
# New Compliance Office and Compliance Officer                                                                                                                                                  1
# Compliance Officer, reporting to President, CEO, Board Committees                                                                                                                             1
# Create Compliance Office, headed by Chief Compliance Officer                                                                                                                                  1
# Name: new_position, dtype: int64

# %%
df[df.new_position.str.contains('Compliance Officer', na = False)]['new_position'].value_counts().sum()
# Out:
# 23

# %% [markdown]
# ## View the cases that have a compliance officer again.
#
# This time you shouldn't have a `...` in the middle of your dataframe.

# %%
df[df.new_position.str.contains('Compliance Officer', na = False)]
# Out:
#       REC_ID                                            COMPANY  \
# 276      655                             Atrium Companies, Inc.
# 362      754                                       Bashas, Inc.
# 415      580                                        Biomet Inc.
# 441      663                                         Boeing Co.
# 664      587                               Columbia Farms, Inc.
# 682      589                                Computer Associates
# 732      667                  Cosmetics Laboratories of America
# 836      592                                 DePuy Orthopaedics
# 1003     596                                           Exactech
# 1063      51  Fisher Sand & Gravel / General Steel (subsid.)...
# 1094     681                                    Friedman's Inc.
# 1362     692                                       IFCO Systems
# 1490     605                                  Johnson & Johnson
# 1512     607                                               KPMG
# 1627     608             Lend Lease (US) Construction LMB, Inc.
# 1657     609                                 Louis Berger Group
# 1661     610                              Love Irrigation, Inc.
# 1760     614                    Maxim Healthcare Services, Inc.
# 2123      91                                Parker Drilling Co.
# 2608     731                                Stryker Orthopedics
# 2853     128    University Medicine and Dentistry of New Jersey
# 3005     645                    Wright Medical Technology, Inc.
# 3033    2523                              Zimmer Holdings, Inc.
#
#                     DISPOSITION_TYPE   PRIMARY_CRIME_CODE SWISS_BANK_PROGRAM  \
# 276        non-prosecution agreement          Immigration                 No
# 362        non-prosecution agreement                 Food                 No
# 415   deferred prosecution agreement                 FCPA                 No
# 441        non-prosecution agreement      Fraud - General                 No
# 664   deferred prosecution agreement          Immigration                 No
# 682   deferred prosecution agreement   Fraud - Securities                 No
# 732        non-prosecution agreement        Environmental                 No
# 836   deferred prosecution agreement            Kickbacks                 No
# 1003  deferred prosecution agreement            Kickbacks                 No
# 1063  deferred prosecution agreement          Fraud - Tax                 No
# 1094       non-prosecution agreement   Fraud - Securities                 No
# 1362       non-prosecution agreement          Immigration                 No
# 1490  deferred prosecution agreement                 FCPA                 No
# 1512  deferred prosecution agreement          Fraud - Tax                 No
# 1627  deferred prosecution agreement      Fraud - General                 No
# 1657  deferred prosecution agreement      Fraud - General                 No
# 1661  deferred prosecution agreement          Immigration                 No
# 1760  deferred prosecution agreement  Fraud - Health Care                 No
# 2123  deferred prosecution agreement                 FCPA                 No
# 2608       non-prosecution agreement            Kickbacks                 No
# 2853  deferred prosecution agreement  Fraud - Health Care                 No
# 3005  deferred prosecution agreement            Kickbacks                 No
# 3033  deferred prosecution agreement            Kickbacks                 No
#
#                                                    USAO        COUNTRY  \
# 276                           Texas - Southern District  United States
# 362                                             Arizona  United States
# 415           USDOJ - Criminal Division - Fraud Section  United States
# 441   California - Central District,Virginia - Easte...  United States
# 664                                      South Carolina  United States
# 682                         New York - Eastern District  United States
# 732                       California - Central District  United States
# 836                                          New Jersey  United States
# 1003                                         New Jersey  United States
# 1063                               USDOJ - Tax Division  United States
# 1094                        New York - Eastern District  United States
# 1362                       New York - Northern District  United States
# 1490          USDOJ - Criminal Division - Fraud Section  United States
# 1512                       New York - Southern District  United States
# 1627                        New York - Eastern District  United States
# 1657                                         New Jersey  United States
# 1661                    Mississippi - Southern District  United States
# 1760                                         New Jersey  United States
# 2123  USDOJ - Criminal Division - Fraud Section,Virg...  United States
# 2608                                         New Jersey  United States
# 2853                                         New Jersey  United States
# 3005                                         New Jersey  United States
# 3033                                         New Jersey  United States
#
#      FINANCIAL_INSTITUTION CASE_NAME CASE_ID DOCKET_NO        DATE  \
# 276                     No       NaN     NaN       NaN  2012-01-01
# 362                     No       NaN     NaN       NaN  2013-08-30
# 415                     No       NaN     NaN       NaN  2012-03-26
# 441                     No       NaN     NaN       NaN  2006-06-01
# 664                     No       NaN     NaN       NaN  2009-11-03
# 682                     No       NaN     NaN       NaN  2004-09-01
# 732                     No       NaN     NaN       NaN  2010-06-01
# 836                     No       NaN     NaN       NaN  2007-09-01
# 1003                    No       NaN     NaN       NaN  2010-12-08
# 1063                    No       NaN     NaN       NaN  2009-04-29
# 1094                    No       NaN     NaN       NaN  2005-11-01
# 1362                    No       NaN     NaN       NaN  2008-12-19
# 1490                    No       NaN     NaN       NaN  2011-01-14
# 1512                   Yes       NaN     NaN       NaN  2005-08-01
# 1627                    No       NaN     NaN       NaN  2012-04-24
# 1657                   Yes       NaN     NaN       NaN  2010-11-05
# 1661                    No       NaN     NaN       NaN  2012-05-22
# 1760                    No       NaN     NaN       NaN  2011-09-06
# 2123                    No       NaN     NaN       NaN  2013-04-16
# 2608                    No       NaN     NaN       NaN  2005-10-01
# 2853                    No       NaN     NaN       NaN  2005-12-01
# 3005                    No       NaN     NaN       NaN  2010-10-01
# 3033                    No       NaN     NaN       NaN  2007-09-01
#
#      JUDGMENT_DATE PLEA_DATE TICKER US_PUBLIC_CO  \
# 276            NaN       NaN    NaN           No
# 362            NaN       NaN    NaN           No
# 415            NaN       NaN    NaN          Yes
# 441            NaN       NaN    NaN          Yes
# 664            NaN       NaN    NaN           No
# 682            NaN       NaN    NaN          Yes
# 732            NaN       NaN    NaN           No
# 836            NaN       NaN    NaN          Yes
# 1003           NaN       NaN    NaN          Yes
# 1063           NaN       NaN    NaN           No
# 1094           NaN       NaN    NaN           No
# 1362           NaN       NaN    NaN          Yes
# 1490           NaN       NaN    NaN          Yes
# 1512           NaN       NaN    NaN           No
# 1627           NaN       NaN    NaN           No
# 1657           NaN       NaN    NaN           No
# 1661           NaN       NaN    NaN           No
# 1760           NaN       NaN    NaN           No
# 2123           NaN       NaN    NaN          Yes
# 2608           NaN       NaN    NaN          Yes
# 2853           NaN       NaN    NaN           No
# 3005           NaN       NaN    NaN          Yes
# 3033           NaN       NaN    NaN          Yes
#
#       ADDITIONAL_REGULATORY_FINE_OR_PAYMENT  COMMUNITY_SERVICE_OR_OTHER  \
# 276                            2,000,000.00                         nan
# 362                                     nan                         nan
# 415                                    0.00                         nan
# 441                                    0.00                         nan
# 664                            1,500,000.00                         nan
# 682                          225,000,000.00                         nan
# 732                                    0.00                         nan
# 836                                    0.00                         nan
# 1003                                   0.00                         nan
# 1063                             668,141.00                         nan
# 1094                                   0.00                2,000,000.00
# 1362                          18,132,000.00                         nan
# 1490                                   0.00                         nan
# 1512                         328,000,000.00                         nan
# 1627                          16,145,000.00                         nan
# 1657                                   0.00                         nan
# 1661                             390,110.00                         nan
# 1760                                   0.00                         nan
# 2123                                    nan                         nan
# 2608                                   0.00                         nan
# 2853                           4,900,000.00                         nan
# 3005                                   0.00                         nan
# 3033                                   0.00                         nan
#
#                FINE  FORFEITURE_DISGORGEMENT  PROBATION_LENGTH    RESTITUTION  \
# 276            0.00                      nan               nan   2,000,000.00
# 362            0.00                      nan             24.00   1,472,487.00
# 415   17,800,000.00                      nan             36.00            nan
# 441   50,000,000.00                      nan             24.00            nan
# 664            0.00                      nan             24.00   1,500,000.00
# 682            0.00                      nan             18.00 225,000,000.00
# 732             nan                      nan               nan            nan
# 836            0.00                      nan             18.00            nan
# 1003           0.00                      nan             12.00            nan
# 1063     500,000.00                      nan             30.00     668,141.00
# 1094           0.00                      nan             36.00            nan
# 1362   2,565,317.00                      nan               nan  18,132,000.00
# 1490  21,400,000.00                      nan             36.00            nan
# 1512 128,000,000.00                      nan             12.00            nan
# 1627  40,500,000.00                      nan             24.00  16,145,000.00
# 1657  18,700,000.00                      nan             24.00            nan
# 1661     125,000.00                      nan             36.00     390,110.00
# 1760  20,000,000.00                      nan             24.00            nan
# 2123  11,760,000.00                      nan             36.00            nan
# 2608           0.00                      nan             18.00            nan
# 2853           0.00                      nan             24.00   4,900,000.00
# 3005           0.00                      nan             12.00            nan
# 3033           0.00                      nan             18.00            nan
#
#       TOTAL_PAYMENT ACCEPTS_RESPONSIBILITY  \
# 276         2000000                    NaN
# 362         1472487                    Yes
# 415        17800000                    Yes
# 441        50000000                    Yes
# 664         1500000                    Yes
# 682       225000000                    Yes
# 732               0                    NaN
# 836               0                    Yes
# 1003              0                    Yes
# 1063        1168141                    Yes
# 1094        2000000                    Yes
# 1362       20697317                    Yes
# 1490       21400000                    Yes
# 1512      456000000                    Yes
# 1627       56645000                    Yes
# 1657       18700000                    Yes
# 1661         515110                    Yes
# 1760       20000000                    Yes
# 2123       11760000                    Yes
# 2608              0                     No
# 2853        4900000                    Yes
# 3005              0                    Yes
# 3033              0                    Yes
#
#                        AGREEMENT_REQUIRED_NEW_POSITIONS  \
# 276                       Yes; Chief Compliance Officer
# 362                       Yes; Chief Compliance Officer
# 415   Yes; Expanded compliance department, complianc...
# 441                             Yes; Compliance Officer
# 664                             Yes; Compliance Officer
# 682   Yes; Two new independent directors to Board, e...
# 732           Yes; Independent Chief Compliance Officer
# 836   Yes; Appoint Chief Compliance Officer as membe...
# 1003  Yes; Compliance Officer, reporting to Presiden...
# 1063                            Yes; Compliance Officer
# 1094  Yes; Compliance Officer, create Audit Committe...
# 1362                  Yes; Full time Compliance Officer
# 1490                      Yes; Chief Compliance Officer
# 1512                      Yes; Chief Compliance Officer
# 1627  Yes; Create new Ethics and Compliance Officer,...
# 1657                            Yes; Compliance Officer
# 1661                            Yes; Compliance Officer
# 1760                      Yes; Chief Compliance Officer
# 2123  Yes; Retaining full time Chief Compliance Offi...
# 2608  Yes; New Compliance Office and Compliance Officer
# 2853                      Yes; Chief Compliance Officer
# 3005                            Yes; Compliance Officer
# 3033  Yes; Create Compliance Office, headed by Chief...
#
#          AGREEMENT_REQUIRED_OUTSIDE_AUDITORS_OR_EXPERTS  \
# 276                                                 NaN
# 362                                                  No
# 415                                                  No
# 441                                                  No
# 664                                                  No
# 682                                                 NaN
# 732                                                 NaN
# 836                                                  No
# 1003                                                 No
# 1063                                                 No
# 1094                                                 No
# 1362  Yes; Independent auditor to conduct I-9 audits...
# 1490                                                 No
# 1512                                                 No
# 1627                                                 No
# 1657                                                 No
# 1661                                                NaN
# 1760                                                 No
# 2123                                                 No
# 2608                                                 No
# 2853                                                 No
# 3005                                                 No
# 3033                                                 No
#
#                                CITATION_AND_DESCRIPTION  \
# 276   Yes (writ of attachment for $5 million and inj...
# 362                                                 NaN
# 415                                                 NaN
# 441   Yes (RICO - possession of competitor documents...
# 664                                                 NaN
# 682   Yes (class actions, In re Computer Associates ...
# 732                                                 NaN
# 836   Yes (RICO and antitrust, McCullough v. Zimmer,...
# 1003                                                NaN
# 1063                                                NaN
# 1094  Yes (breach of implied covenant, breach of fid...
# 1362                                                NaN
# 1490  Shareholder derivative lawsuit claiming breach...
# 1512  Shalam v. KPMG, LLP, 907 N.Y.S.2d 103, 2010 BL...
# 1627                                                NaN
# 1657                                                NaN
# 1661                                                NaN
# 1760  Quit tam settlements as part of HHS-OIG settle...
# 2123                                                NaN
# 2608                 Somerville v. Stryker Orthopaedics
# 2853   Qui tam suits settled with False Claims Act suit
# 3005                                                NaN
# 3033                                                NaN
#
#                            CIVIL_JUDGMENT_OR_SETTLEMENT  \
# 276   Unknown (couldn't find any information except ...
# 362                                                 NaN
# 415                                                 NaN
# 441                                                 NaN
# 664                                                 NaN
# 682                                           163000000
# 732                                                 NaN
# 836                                                   0
# 1003                                                NaN
# 1063                                                NaN
# 1094                                           14900000
# 1362                                                NaN
# 1490                                                NaN
# 1512  Discontinued against KPMG; dismissed complaint...
# 1627                                                NaN
# 1657                                                NaN
# 1661                                                NaN
# 1760                                                NaN
# 2123                                                NaN
# 2608                                                NaN
# 2853                                                NaN
# 3005                                                NaN
# 3033                                                NaN
#
#                          COMPLIANCE_PROGRAM_DESCRIPTION  \
# 276   Hire full time chief compliance officer and co...
# 362   Imposing discipline on involved employees; new...
# 415   Compliance department expanded, policy review ...
# 441   Training; discipline; prohibiting retaliation;...
# 664   Designation of compliance officer; ICE reporti...
# 682   Auditing; policy changes; data collection; con...
# 732                                             Unknown
# 836   Appoint Compliance Officer as member of Manage...
# 1003  Compliance code requiring adherence to the Rev...
# 1063  Designate Compliance Officer to oversee implem...
# 1094  Have number of independent directors required ...
# 1362  Adoption and maintenance of a comprehensive, r...
# 1490  Including periodic reviews and reports to DOJ(...
# 1512  Policy changes; confidential reporting; compli...
# 1627  New auditor position, new documentation, proce...
# 1657  Complaince, training, hotline, new compliance ...
# 1661  Use of e-verify, training, designate complianc...
# 1760  Including appointment of chief compliance officer
# 2123  Compliance and ethics program; review and modi...
# 2608  Compliance Office, needs assessment, training,...
# 2853  New policies; confidential reporting; training...
# 3005  Compliance program; training; hotline; needs a...
# 3033  Retain monitor to oversee compliance improvements
#
#      COMPLIANCE_PROGRAM_REQUIRED_BY_AGREEMENT  \
# 276                                       Yes
# 362                                       Yes
# 415                                       Yes
# 441                                       Yes
# 664                                       Yes
# 682                                       Yes
# 732                                   Unknown
# 836                                       Yes
# 1003                                      Yes
# 1063                                      Yes
# 1094                                      Yes
# 1362                                      Yes
# 1490                                      Yes
# 1512                                      Yes
# 1627                                      Yes
# 1657                                      Yes
# 1661                                      Yes
# 1760                                      Yes
# 2123                                      Yes
# 2608                                      Yes
# 2853                                      Yes
# 3005                                      Yes
# 3033                                      Yes
#
#                       COMPLIANCE_REQUIRED_BY_REGULATORS  \
# 276                                                  No
# 362                                                  No
# 415          Yes; HHS-OIG Corporate Integrity Agreement
# 441   Yes; Interim Agreement with Air Force: maintai...
# 664                                                 NaN
# 682                                                 NaN
# 732                                                 NaN
# 836                                                  No
# 1003                                                NaN
# 1063                                                Yes
# 1094                 Yes; Corporate Integrity Agreement
# 1362                                                NaN
# 1490                                                 No
# 1512                                                Yes
# 1627                                                 No
# 1657                                                 No
# 1661                                                 No
# 1760    Yes; Corporate Integrity Agreement with OIG-HHS
# 2123                                                NaN
# 2608                                                NaN
# 2853                                                NaN
# 3005  Yes; Civil Settlement Agreement with civil div...
# 3033    Yes; Corporate Integrity Agreement with OIG-HHS
#
#                                              CRIME_DESC  \
# 276                                         Immigration
# 362     Food-related USDA violations (mislabeling meat)
# 415         Anti-Kickback Statute (payments to doctors)
# 441   Federal procurement fraud, conflict of interes...
# 664                       Immigration, false statements
# 682            Securities fraud; obstruction of justice
# 732                                                 NaN
# 836                                   Anti-Kickback Law
# 1003                                  Anti-Kickback Law
# 1063                                          Tax fraud
# 1094  Securities fraud; consp to commit bank and wir...
# 1362  Immigration - hiring and employment of illegal...
# 1490                                               FCPA
# 1512  Tax fraud, conspiracy to defraud IRS; tax evasion
# 1627           Conspiracy to commit Wire and Mail Fraud
# 1657                               Major Frauds Statute
# 1661    Immigration - harboring, employment, conspiracy
# 1760                                  Health Care Fraud
# 2123                       FCPA anti-bribery provisions
# 2608                                  Anti-Kickback Law
# 2853                                  Health care fraud
# 3005                              Anti-Kickback Statute
# 3033                                  Anti-Kickback Law
#
#                             DESCRIPTION_OF_PAYMENTS  \
# 276                                             NaN
# 362                                             NaN
# 415                                             NaN
# 441                                             NaN
# 664                                             NaN
# 682                                             NaN
# 732                                             NaN
# 836                                             NaN
# 1003                                            NaN
# 1063                                            NaN
# 1094                                            NaN
# 1362                                            NaN
# 1490                                            NaN
# 1512                                            NaN
# 1627                                            NaN
# 1657                                            NaN
# 1661                                            NaN
# 1760   Civil settlments, including False Claims Act
# 2123                                            NaN
# 2608                                            NaN
# 2853  Settlement of False Claims Act, qui tam suits
# 3005                                            NaN
# 3033                                            NaN
#
#      DOES_AGREEMENT_DISCUSS_REASONS_OR_RELEVENT_CONSIDERATIONS_FOR_LENIENCY  \
# 276                                                   .
# 362   Yes; cooperation, acknowledging responsibility...
# 415   Yes; remedial actions, cooperation, acceptance...
# 441   Yes; in exchange for good faith performance of...
# 664   Yes; acceptance of responsibility, compliance,...
# 682   Yes; acceptance of responsibility, cooperation...
# 732                                                   .
# 836   Yes; remedial actions, cooperation, acceptance...
# 1003  Yes; additional remediation, acknowledging res...
# 1063  Yes; acceptance of responsibility, cooperation...
# 1094       Yes; remedial actions, cooperation, payment.
# 1362  Yes; acceptance of responsibility, cooperation...
# 1490  Yes; voluntary and timely disclosure, internal...
# 1512                                                 No
# 1627  Yes; acceptance of responsibility, cooperation...
# 1657  Yes; acceptance of responsibility, cooperation...
# 1661  Yes; acceptance of responsibility, cooperation...
# 1760                                                 No
# 2123  Yes; cooperation, extensive remediation incudl...
# 2608                                                  .
# 2853  Yes; remedial actions, cooperation, payment of...
# 3005  Yes; remediation, acknowledging responsibility...
# 3033  Yes; substantial assistance, enhanced complian...
#
#                          DOJ_CAN_UNILATERALLY_TERMINATE  \
# 276                                                 NaN
# 362                                                 Yes
# 415                                                 Yes
# 441   No; But "conduct by a Boeing employee classifi...
# 664                                                 Yes
# 682                                                 Yes
# 732                                                 NaN
# 836                                                 Yes
# 1003                                                Yes
# 1063                                                Yes
# 1094                                                Yes
# 1362                                                Yes
# 1490  Yes; Provides for an extension of the term of ...
# 1512                                                Yes
# 1627                                                Yes
# 1657                                                Yes
# 1661                                                Yes
# 1760                                                Yes
# 2123                                                Yes
# 2608                                                Yes
# 2853                                                Yes
# 3005                                     Yes; If breach
# 3033                                                Yes
#
#                               FINE_CALCULATION_INCLUDED  \
# 276                                                 NaN
# 362                                                  No
# 415                                                  No
# 441                                                  No
# 664                                                  No
# 682                                                  No
# 732                                                 NaN
# 836                                                  No
# 1003                                                 No
# 1063                                                 No
# 1094                                                 No
# 1362                                                 No
# 1490  Yes; 25% reduction below bottom of guidelines ...
# 1512                                                 No
# 1627                                                 No
# 1657                                                 No
# 1661                Yes; Bottom end of Guidelines range
# 1760                                                 No
# 2123                     Yes; 20% below bottom of range
# 2608                                                 No
# 2853                                                 No
# 3005                                                 No
# 3033                                                 No
#
#                                        FINE_DESCRIPTION  \
# 276   $2,000,000 to Department of Homeland Security ...
# 362   $1.47 million went to Tuscon Community Food Ba...
# 415   None; simultaneous settlement with DOJ Civil D...
# 441   $50M penalty, $565M civil settlement; $1.9M to...
# 664                                               $1.5M
# 682   $225M restitution; $163M civil compensation in...
# 732                                                 NaN
# 836   $84.7 million civil settlement reached with DO...
# 1003  Separate $2,991,889 settlement of administrati...
# 1063  $668,141 restitution for unpaid lax liability;...
# 1094  $2M to the United States Postal Inspection Ser...
# 1362  $18,132,000 forfeiture; $2,565,317.51 in fines...
# 1490  DePuy International Ltd. (subsidiary) settled ...
# 1512      $456M total, of which $228M consists of fines
# 1627                                                NaN
# 1657                                                NaN
# 1661                                         $1 million
# 1760                                                NaN
# 2123                                                NaN
# 2608                                               None
# 2853  Full restitution in amount determined by Monit...
# 3005  $7.9 million to HHS-OIG, as part of joint sett...
# 3033                                               None
#
#      INDEP_MONITOR_REQUIRED  \
# 276                      No
# 362                      No
# 415                     Yes
# 441                     Yes
# 664                      No
# 682                     Yes
# 732                      No
# 836                     Yes
# 1003                    Yes
# 1063                     No
# 1094                     No
# 1362                     No
# 1490                     No
# 1512                    Yes
# 1627                     No
# 1657                    Yes
# 1661                     No
# 1760                    Yes
# 2123                     No
# 2608                    Yes
# 2853                    Yes
# 3005                    Yes
# 3033                    Yes
#
#              MUST_COMPORT_WITH_USSG_OR_AUDIT_COMPLIANCE  \
# 276                                                 NaN
# 362                                                  No
# 415                                                  No
# 441        Yes; Periodic auditing of compliance program
# 664   Yes; Use of e-Verify program, annual review of...
# 682   Yes; ERP information technology system to audi...
# 732                                                 NaN
# 836                                                  No
# 1003                                                NaN
# 1063  Yes; Compliance Officer must evaluate periodic...
# 1094                                                 No
# 1362                                                 No
# 1490                              Yes; Risk assessments
# 1512                                Yes; U.S.S.G. 8B2.1
# 1627                                                 No
# 1657                                                 No
# 1661                                                 No
# 1760                                                 No
# 2123                   Yes; Annual report to government
# 2608                                                 No
# 2853                                                 No
# 3005                                                 No
# 3033                                                 No
#
#             OTHER_AGREEMENT  \
# 276                     NaN
# 362                     NaN
# 415                     NaN
# 441    Interim Admin. Agmt.
# 664                     NaN
# 682                     NaN
# 732                     NaN
# 836                     NaN
# 1003                    NaN
# 1063                    NaN
# 1094                    NaN
# 1362                    NaN
# 1490                    NaN
# 1512                    NaN
# 1627                    NaN
# 1657                    NaN
# 1661                    NaN
# 1760  Corp. Integrity Agmt.
# 2123                    NaN
# 2608                    NaN
# 2853                    NaN
# 3005                    NaN
# 3033                    NaN
#
#             OTHER_AGREEMENT_REQUIRED_GOVERNANCE_CHANGES  \
# 276                                                 NaN
# 362                                                  No
# 415      Yes; Detailed rules for Consulting Agreements)
# 441                                                  No
# 664                                                  No
# 682   Yes; Report of Compliance Committee in each pr...
# 732                                                 NaN
# 836   Yes; Compliance Office approve consulting serv...
# 1003  Yes; Compliance Office approve consulting serv...
# 1063                                                 No
# 1094  Yes; "establish a centralized, analytics-based...
# 1362                                                 No
# 1490                                                 No
# 1512  Yes; Substantial changes, including permanent ...
# 1627                                                 No
# 1657                       Yes; New obligations of CFO)
# 1661                                                NaN
# 1760                                                 No
# 2123                                                 No
# 2608  Yes; New procedures for review of consulting a...
# 2853                                                 No
# 3005                                                 No
# 3033                                                 No
#
#      OTHER_COMPLIANCE_OFFICER_OR_CONSULTANT_REQUIRED  \
# 276                                               No
# 362                                               No
# 415                                               No
# 441                                              Yes
# 664                                               No
# 682                                              Yes
# 732                                              Yes
# 836                                              Yes
# 1003                                              No
# 1063                                              No
# 1094                                             Yes
# 1362                                              No
# 1490                                              No
# 1512                                             Yes
# 1627                                              No
# 1657                                             Yes
# 1661                                             Yes
# 1760                                             Yes
# 2123                                             Yes
# 2608                                              No
# 2853                                              No
# 3005                                             Yes
# 3033                                             Yes
#
#                                     PARALLEL_CIVIL_SUIT  \
# 276                                                 Yes
# 362                                                 NaN
# 415                                                  No
# 441                                                 Yes
# 664                                                  No
# 682                                                 Yes
# 732                                                 NaN
# 836                                                 Yes
# 1003                                                 No
# 1063                                                 No
# 1094                                                Yes
# 1362                                                 No
# 1490                                                Yes
# 1512                                                Yes
# 1627                                                 No
# 1657                                                 No
# 1661                                                 No
# 1760                                                Yes
# 2123                                                NaN
# 2608                                                Yes
# 2853                                                Yes
# 3005  No; Implant lawsuits relate to design of produ...
# 3033                                                 No
#
#          PARALLEL_REGULATORY_ACTION_OR_LOCAL_PROSECUTOR  \
# 276                                                 NaN
# 362                                                 NaN
# 415             Yes; HHS-OIG ($26.9 million settlement)
# 441                                                 Yes
# 664                                                 NaN
# 682   Yes; SEC (joint settlement with USADO - no sep...
# 732                                                 NaN
# 836   Yes; HHS-OIG (settlement for $84.7 million and...
# 1003  Yes; OIG-HHS (see Corporate Integrity Agreemen...
# 1063                                                NaN
# 1094  Yes; SEC (injunction from future violations of...
# 1362                                                 No
# 1490                                           Yes; SEC
# 1512  Yes; Restitution to IRS of $228,000,000, IRS p...
# 1627                                                 No
# 1657                                                 No
# 1661                                           Yes; SEC
# 1760                                       Yes; HHS-OIG
# 2123                                           Yes; SEC
# 2608                                                 No
# 2853                                  Yes; DOJ, OIG-HHS
# 3005                                       Yes; HHS-OIG
# 3033                                       Yes; HHS-OIG
#
#      PRE_AGREEMENT_COMPLIANCE  \
# 276                       Yes
# 362                       Yes
# 415                       Yes
# 441                       Yes
# 664                       Yes
# 682                       Yes
# 732                       NaN
# 836                       Yes
# 1003                      Yes
# 1063                      Yes
# 1094                      Yes
# 1362                      Yes
# 1490                      Yes
# 1512                       No
# 1627                      Yes
# 1657                      Yes
# 1661                       No
# 1760                      Yes
# 2123                      Yes
# 2608                       No
# 2853                      Yes
# 3005                      Yes
# 3033                      Yes
#
#                    PRE_AGREEMENT_COMPLIANCE_DESCRIPTION PRIVACY_WAIVER  \
# 276   Yes; Substantial remedial measures; revising i...            NaN
# 362   Yes; Thorough internal investigation and volun...             No
# 415                     Yes; Pre-agreement ethics codes             No
# 441   Yes; Changes to ethics and compliance program;...             No
# 664   Yes; Cites significant remedial actions taken ...             No
# 682   Yes; Terminate employees; add two independent ...            Yes
# 732                                                 NaN            NaN
# 836   Yes; Compliance policies, compliance officer a...             No
# 1003  Yes; Code of compliance and ethics, governance...             No
# 1063             Yes; Drafted a Code of Business Ethics             No
# 1094  Yes; Internal investigation; sharing of result...            Yes
# 1362  Yes; Independent review of hiring practices by...             No
# 1490  Yes; "significant remediation" and global revi...             No
# 1512                                     No; None cited            Yes
# 1627  Yes; Describes "a number of remedial actions" ...             No
# 1657  Yes; "extensive reforms and remedial measures"...             No
# 1661                                                 No             No
# 1760  Yes; Extensive remedial efforts cited, includi...             No
# 2123  Yes; Extensive remediation including ending re...             No
# 2608                                     No; None cited             No
# 2853  Yes; Cites "remedial actions to date?√É¬ô with...            Yes
# 3005  Yes; Described new policies, new Chief Complia...             No
# 3033  Yes; Appointing Chief Compliance Officer, new ...             No
#
#       REGULATORY_DISGORGEMENT_RESTITUTION_FORFEITURE  REGULATORY_FINE  \
# 276                                              nan              nan
# 362                                              nan              nan
# 415                                              nan    26,900,000.00
# 441                                     1,900,000.00   595,000,000.00
# 664                                              nan              nan
# 682                                             0.00             0.00
# 732                                              nan              nan
# 836                                             0.00    84,700,000.00
# 1003                                            0.00     2,991,889.00
# 1063                                             nan              nan
# 1094                                            0.00             0.00
# 1362                                            0.00             0.00
# 1490                                   48,666,316.00             0.00
# 1512                                  228,000,000.00   100,000,000.00
# 1627                                            0.00             0.00
# 1657                                             nan              nan
# 1661                                            0.00     1,500,000.00
# 1760                                             nan   130,000,000.00
# 2123                                    4,090,000.00              nan
# 2608                                            0.00             0.00
# 2853                                             nan     2,000,000.00
# 3005                                            0.00     7,900,000.00
# 3033                                            0.00   196,500,000.00
#
#                                              REG_AGENCY STATEMENT_OF_FACTS  \
# 276   Dept. of Homeland Security - Immigration & Cus...                NaN
# 362                                Dept. of Agriculture                Yes
# 415   Dept. of Health & Human Services - Office of t...                 No
# 441   National Aeronautics and Space Administration ...                Yes
# 664   Dept. of Homeland Security;Dept. of Homeland S...                Yes
# 682            Securities and Exchange Commission (SEC)                Yes
# 732                                                 NaN                NaN
# 836   Dept. of Health & Human Services - Office of t...                 No
# 1003  Dept. of Health & Human Services - Office of t...                 No
# 1063  Dept. of the Treasury - Internal Revenue Servi...                Yes
# 1094           Securities and Exchange Commission (SEC)                Yes
# 1362  Social Security Administration; Dept. of Homel...                 No
# 1490  Securities and Exchange Commission (SEC); othe...                Yes
# 1512  Dept. of the Treasury - Internal Revenue Servi...                Yes
# 1627   other - New York City District Attorney's Office                Yes
# 1657  Dept. of Justice - Civil Division - Fraud Sect...                Yes
# 1661  Dept. of Homeland Security - Immigration & Cus...                Yes
# 1760  Dept. of Health & Human Services - Office of t...                Yes
# 2123           Securities and Exchange Commission (SEC)                Yes
# 2608  Dept. of Health & Human Services - Office of t...                 No
# 2853                                               None                 No
# 3005  U.S. Postal Inspection Service (USPIS); Dept. ...                 No
# 3033  Dept. of Health & Human Services; U.S. Postal ...                Yes
#
#       TOTAL_REGULATORY                                    UNRELATED_TERMS  \
# 276               0.00                                                NaN
# 362                nan                                                 No
# 415      26,900,000.00                                                 No
# 441     596,900,000.00                                                 No
# 664               0.00                                                 No
# 682               0.00                                                 No
# 732               0.00                                                NaN
# 836      84,700,000.00                                                 No
# 1003      2,991,889.00                                                 No
# 1063              0.00                                                 No
# 1094              0.00  Yes; Can object to corporate charter for any r...
# 1362              0.00                                                 No
# 1490     48,666,316.00                                                 No
# 1512    328,000,000.00                                                 No
# 1627              0.00                                                 No
# 1657              0.00                                                 No
# 1661      1,500,000.00                                                 No
# 1760    130,000,000.00                                                 No
# 2123      4,090,000.00                                                 No
# 2608              0.00                                                 No
# 2853      2,000,000.00                                                 No
# 3005      7,900,000.00                                                 No
# 3033    196,500,000.00                                                 No
#
#       AGMT_YEAR        SOURCE  \
# 276    2,012.00  FOIA request
# 362    2,013.00           NaN
# 415    2,012.00           NaN
# 441    2,006.00           NaN
# 664    2,009.00           NaN
# 682    2,004.00           NaN
# 732    2,010.00  FOIA request
# 836    2,007.00           NaN
# 1003   2,010.00           NaN
# 1063   2,009.00           NaN
# 1094   2,005.00           NaN
# 1362   2,008.00           NaN
# 1490   2,011.00           NaN
# 1512   2,005.00           NaN
# 1627   2,012.00           NaN
# 1657   2,010.00           NaN
# 1661   2,012.00           NaN
# 1760   2,011.00           NaN
# 2123   2,013.00           NaN
# 2608   2,005.00           NaN
# 2853   2,005.00           NaN
# 3005   2,010.00           NaN
# 3033   2,007.00           NaN
#
#                                                   NOTES required_new_position  \
# 276                                                 NaN                  True
# 362                                                 NaN                  True
# 415                                                 NaN                  True
# 441   Information regarding the Interim Agreement: h...                  True
# 664                                                 NaN                  True
# 682   Additional civil case brought against the law ...                  True
# 732   Acquired by Alberto-Culver. I wasn't able to f...                  True
# 836   Corporate Integrity Agreement with HHS-OIG: ht...                  True
# 1003  Corporate Integrity Agreement found at: http:/...                  True
# 1063                                                NaN                  True
# 1094  See SEC Litigation: http://www.sec.gov/litigat...                  True
# 1362  Managers were indicted in Texas in 2010: http:...                  True
# 1490  Johnson & Johnson is parent company of DePuy, ...                  True
# 1512                                                NaN                  True
# 1627                                                NaN                  True
# 1657                                                NaN                  True
# 1661                                                NaN                  True
# 1760                                                NaN                  True
# 2123                                                NaN                  True
# 2608                                                NaN                  True
# 2853                                                NaN                  True
# 3005                                                NaN                  True
# 3033                                                NaN                  True
#
#                                            new_position
# 276                            Chief Compliance Officer
# 362                            Chief Compliance Officer
# 415   Expanded compliance department, compliance off...
# 441                                  Compliance Officer
# 664                                  Compliance Officer
# 682   Two new independent directors to Board, establ...
# 732                Independent Chief Compliance Officer
# 836   Appoint Chief Compliance Officer as member of ...
# 1003  Compliance Officer, reporting to President, CE...
# 1063                                 Compliance Officer
# 1094  Compliance Officer, create Audit Committee, No...
# 1362                       Full time Compliance Officer
# 1490                           Chief Compliance Officer
# 1512                           Chief Compliance Officer
# 1627  Create new Ethics and Compliance Officer, full...
# 1657                                 Compliance Officer
# 1661                                 Compliance Officer
# 1760                           Chief Compliance Officer
# 2123  Retaining full time Chief Compliance Officer; ...
# 2608       New Compliance Office and Compliance Officer
# 2853                           Chief Compliance Officer
# 3005                                 Compliance Officer
# 3033  Create Compliance Office, headed by Chief Comp...

# %% [markdown]
# ## What were the most popular crimes that required a compliance officer's appointment?

# %%
comp_officer = df[df.new_position.str.contains('Compliance Officer', na = False)]
comp_officer.CRIME_DESC.value_counts().head()
# Out:
# Anti-Kickback Law                                                                   4
# Immigration, false statements                                                       1
# FCPA                                                                                1
# Conspiracy to commit Wire and Mail Fraud                                            1
# Federal procurement fraud, conflict of interest, use of competitor's information    1
# Name: CRIME_DESC, dtype: int64

# %% [markdown]
# # Make a comparison between two groups in the full dataset
#
# For example, "cases before 2003 were likely to be about this, but after 2003 they became about something else."

# %%
df['year'] = df.DATE.str.extract('(\d{4})')
df.year = df.year.astype(float)

cases_before_2003 = df[df.year <= 2003]
cases_before_2003.CRIME_DESC.value_counts(ascending=True).plot(kind='barh')
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.

# %%
cases_after_2003 = df[df.year > 2003]
cases_after_2003.CRIME_DESC.value_counts(ascending=True).tail(10).plot(kind='barh')
